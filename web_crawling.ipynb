# %% [markdown]
# # Read http://docs.python-requests.org/en/master/ for using Request Python Package
# ## It is also a great tutorial for various ways of internet access

# %% [markdown]
# ## Web Scraping the President's lies in 16 lines of Python
# ### http://www.dataschool.io/python-web-scraping-of-president-trumps-lies/

# %%
import requests
r = requests.get('https://www.nytimes.com/interactive/2017/06/23/opinion/trumps-lies.html')

from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text, 'html.parser')
results = soup.find_all('span', attrs={'class':'short-desc'})

records = []
for result in results:
    date = result.find('strong').text[0:-1] + ', 2017'
    lie = result.contents[1][1:-2]
    explanation = result.find('a').text[1:-1]
    url = result.find('a')['href']
    records.append((date, lie, explanation, url))

import pandas as pd
df = pd.DataFrame(records, columns=['date', 'lie', 'explanation', 'url'])
df['date'] = pd.to_datetime(df['date'])
df.to_csv('trump_lies.csv', index=False, encoding='utf-8')

# %%
df
# Out:
#           date                                                lie  \
# 0   2017-01-21  I wasn't a fan of Iraq. I didn't want to go in...
# 1   2017-01-21  A reporter for Time magazine — and I have been...
# 2   2017-01-23  Between 3 million and 5 million illegal votes ...
# 3   2017-01-25  Now, the audience was the biggest ever. But th...
# 4   2017-01-25  Take a look at the Pew reports (which show vot...
# 5   2017-01-25  You had millions of people that now aren't ins...
# 6   2017-01-25  So, look, when President Obama was there two w...
# 7   2017-01-26  We've taken in tens of thousands of people. We...
# 8   2017-01-26  I cut off hundreds of millions of dollars off ...
# 9   2017-01-28  The coverage about me in the @nytimes and the ...
# 10  2017-01-29  The Cuban-Americans, I got 84 percent of that ...
# 11  2017-01-30  Only 109 people out of 325,000 were detained a...
# 12  2017-02-03  Professional anarchists, thugs and paid protes...
# 13  2017-02-04  After being forced to apologize for its bad an...
# 14  2017-02-05  We had 109 people out of hundreds of thousands...
# 15  2017-02-06  I have already saved more than $700 million wh...
# 16  2017-02-06  It's gotten to a point where it is not even be...
# 17  2017-02-06  The failing @nytimes was forced to apologize t...
# 18  2017-02-06  And the previous administration allowed it to ...
# 19  2017-02-07  And yet the murder rate in our country is the ...
# 20  2017-02-07  I saved more than $600 million. I got involved...
# 21  2017-02-09  Chris Cuomo, in his interview with Sen. Blumen...
# 22  2017-02-09  Sen. Richard Blumenthal now misrepresents what...
# 23  2017-02-10  I don’t know about it. I haven’t seen it. What...
# 24  2017-02-12  Just leaving Florida. Big crowds of enthusiast...
# 25  2017-02-16  We got 306 because people came out and voted l...
# 26  2017-02-16  That’s the other thing that was wrong with the...
# 27  2017-02-16  Walmart announced it will create 10,000 jobs i...
# 28  2017-02-16  When WikiLeaks, which I had nothing to do with...
# 29  2017-02-16  We had a very smooth rollout of the travel ban...
# ..         ...                                                ...
# 150 2017-10-03  But that's an expensive plane that you can't s...
# 151 2017-10-06  I was able to reduce the price of the Lockheed...
# 152 2017-10-06  We're the highest-taxed developed nation in th...
# 153 2017-10-06  They also just said that there has been absolu...
# 154 2017-10-06  This tax cut and tax reform is going very well...
# 155 2017-10-07       We're the highest-taxed nation in the world.
# 156 2017-10-07  The Coast Guard, in Texas, and all over, but w...
# 157 2017-10-07  Obama should have never gotten out the way he ...
# 158 2017-10-10  The Failing @nytimes set Liddle' Bob Corker up...
# 159 2017-10-10       We're the highest-taxed nation in the world.
# 160 2017-10-11  We have missiles that can knock out a missile ...
# 161 2017-10-16      We're the highest-taxed country in the world.
# 162 2017-10-16  I hear that Ireland is going to be reducing th...
# 163 2017-10-16  If you look at President Obama and other presi...
# 164 2017-10-16  All I can say is it's totally fake news, just ...
# 165 2017-10-17       We're the highest taxed nation in the world.
# 166 2017-10-17  Right now, we are the highest-taxed nation any...
# 167 2017-10-17  As far as I'm concerned, I think we're really ...
# 168 2017-10-17  We're the highest-taxed nation in the world. W...
# 169 2017-10-17  Well, we're the highest-taxed nation in the wo...
# 170 2017-10-17  I wish President Obama didn't get out the way ...
# 171 2017-10-18  Democrat Congresswoman totally fabricated what...
# 172 2017-10-18       The Coast Guard in Texas saved 16,000 lives.
# 173 2017-10-18      Nobody has ever heard of a five hitting land.
# 174 2017-10-24  Under our plan, more than 30 million Americans...
# 175 2017-10-25      We have trade deficits with almost everybody.
# 176 2017-10-27  Wacky & totally unhinged Tom Steyer, who has b...
# 177 2017-11-01  Again, we're the highest-taxed nation, just ab...
# 178 2017-11-07  When you look at the city with the strongest g...
# 179 2017-11-11  I'd rather have him  – you know, work with him...
#
#                                            explanation  \
# 0     He was for an invasion before he was against it.
# 1    Trump was on the cover 11 times and Nixon appe...
# 2               There's no evidence of illegal voting.
# 3    Official aerial photos show Obama's 2009 inaug...
# 4              The report never mentioned voter fraud.
# 5    The real number is less than 1 million, accord...
# 6    There were no gun homicide victims in Chicago ...
# 7                       Vetting lasts up to two years.
# 8               Most of the cuts were already planned.
# 9                                 It never apologized.
# 10                       There is no support for this.
# 11   At least 746 people were detained and processe...
# 12            There is no evidence of paid protesters.
# 13                                It never apologized.
# 14                  About 60,000 people were affected.
# 15   Much of the price drop was projected before Tr...
# 16    Terrorism has been reported on, often in detail.
# 17                                It didn't apologize.
# 18                   The group’s origins date to 2004.
# 19                It was higher in the 1980s and '90s.
# 20   The Defense Department projected this price dr...
# 21              It was part of Cuomo's first question.
# 22       The Gorsuch comments were later corroborated.
# 23         Trump knew about Flynn's actions for weeks.
# 24                             The media did cover it.
# 25   George H.W. Bush, Bill Clinton and Barack Obam...
# 26           Delta's problems happened two days later.
# 27   The jobs are a result of its investment plans ...
# 28   Not always. They have released classified info...
# 29                            The rollout was chaotic.
# ..                                                 ...
# 150  The cost cuts were planned before he became pr...
# 151  The cost cuts were planned before he became pr...
# 152                                         We're not.
# 153                        The Senate didn't say that.
# 154                                         We're not.
# 155                                         We're not.
# 156                        The real number is smaller.
# 157                  The group’s origins date to 2004.
# 158  Corker asked the Times reporter to record the ...
# 159                                         We're not.
# 160        The effectiveness rate is about 60 percent.
# 161                                         We're not.
# 162          Ireland has no plans to cut its tax rate.
# 163  They did call families of soldiers killed in a...
# 164     Trump himself has bragged about groping women.
# 165                                         We're not.
# 166                                         We're not.
# 167  Taxes in the U.S. are lower than in most devel...
# 168                                         We're not.
# 169                                         We're not.
# 170                  The group’s origins date to 2004.
# 171  The wife confirmed Representative Frederica Wi...
# 172                       The real number was smaller.
# 173            Category 5 storms have hit land before.
# 174  The real number is estimated to be less than 1...
# 175  We have trade surpluses with more than 100 cou...
# 176  Steyer has financially supported many winning ...
# 177                                         We're not.
# 178  Several other cities, including New York and L...
# 179  There is no evidence that Democrats "set up" R...
#
#                                                    url
# 0    https://www.buzzfeed.com/andrewkaczynski/in-20...
# 1    http://nation.time.com/2013/11/06/10-things-yo...
# 2    https://www.nytimes.com/2017/01/23/us/politics...
# 3    https://www.nytimes.com/2017/01/21/us/politics...
# 4    https://www.nytimes.com/2017/01/24/us/politics...
# 5    https://www.nytimes.com/2017/03/13/us/politics...
# 6    https://www.dnainfo.com/chicago/2017-chicago-m...
# 7    https://www.nytimes.com/interactive/2017/01/29...
# 8    https://www.washingtonpost.com/news/fact-check...
# 9    https://www.nytimes.com/2016/11/13/us/election...
# 10   http://www.pewresearch.org/fact-tank/2016/11/1...
# 11   http://markets.on.nytimes.com/research/stocks/...
# 12   https://www.nytimes.com/2017/01/28/nyregion/jf...
# 13   https://www.nytimes.com/2016/11/13/us/election...
# 14   http://www.politifact.com/truth-o-meter/statem...
# 15   https://www.washingtonpost.com/news/fact-check...
# 16   https://www.nytimes.com/2017/02/07/us/politics...
# 17   https://www.nytimes.com/2016/11/13/us/election...
# 18   https://www.nytimes.com/2015/11/19/world/middl...
# 19   http://www.politifact.com/truth-o-meter/statem...
# 20   https://www.washingtonpost.com/news/fact-check...
# 21   http://transcripts.cnn.com/TRANSCRIPTS/1702/09...
# 22   https://www.washingtonpost.com/news/fact-check...
# 23   http://www.factcheck.org/2017/02/trump-spins-f...
# 24   http://www.palmbeachpost.com/news/national-gov...
# 25   https://www.nytimes.com/2017/02/16/us/politics...
# 26   https://www.washingtonpost.com/news/fact-check...
# 27   https://www.nytimes.com/interactive/2017/busin...
# 28   http://www.politifact.com/truth-o-meter/articl...
# 29   https://www.washingtonpost.com/news/fact-check...
# ..                                                 ...
# 150  https://www.washingtonpost.com/news/fact-check...
# 151  https://www.washingtonpost.com/news/fact-check...
# 152  http://www.politifact.com/truth-o-meter/statem...
# 153  http://www.cnn.com/TRANSCRIPTS/1710/04/ip.02.html
# 154  http://www.politifact.com/truth-o-meter/statem...
# 155  http://www.politifact.com/truth-o-meter/statem...
# 156  https://content.govdelivery.com/accounts/USDHS...
# 157  https://www.nytimes.com/2015/11/19/world/middl...
# 158  https://www.nytimes.com/2017/10/10/reader-cent...
# 159  http://www.politifact.com/truth-o-meter/statem...
# 160  https://warontherocks.com/2017/10/deadly-overc...
# 161  http://www.politifact.com/truth-o-meter/statem...
# 162          https://www.snopes.com/trump-ireland-tax/
# 163  https://www.nytimes.com/2017/10/16/us/politics...
# 164  https://www.washingtonpost.com/news/fact-check...
# 165  http://www.politifact.com/truth-o-meter/statem...
# 166  http://www.politifact.com/truth-o-meter/statem...
# 167  http://www.politifact.com/truth-o-meter/statem...
# 168  http://www.politifact.com/truth-o-meter/statem...
# 169  http://www.politifact.com/truth-o-meter/statem...
# 170  https://www.nytimes.com/2015/11/19/world/middl...
# 171  http://time.com/4993045/myeshia-johnson-donald...
# 172  https://content.govdelivery.com/accounts/USDHS...
# 173  http://www.cnn.com/2017/09/07/us/three-categor...
# 174  http://www.businessinsider.com/trump-small-bus...
# 175  https://www.bea.gov/newsreleases/international...
# 176  https://www.opensecrets.org/donor-lookup/resul...
# 177  http://www.politifact.com/truth-o-meter/statem...
# 178  http://www.politifact.com/truth-o-meter/statem...
# 179  https://www.nytimes.com/interactive/2017/12/10...
#
# [180 rows x 4 columns]

# %% [markdown]
# ## 파이선으로 특정 키워드를 포함하는 신문기사 웹크롤링
# ### http://yoonpunk.tistory.com/4

# %%
"""네이버 뉴스 기사 웹 크롤러 모듈"""
 
from bs4 import BeautifulSoup
import urllib.request
 
# 출력 파일 명
OUTPUT_FILE_NAME = 'output.txt'
# 긁어 올 URL
URL = 'http://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=103&oid=055'\
      '&aid=0000445667'
 
 
# 크롤링 함수
def get_text(URL):
    source_code_from_URL = urllib.request.urlopen(URL)
    soup = BeautifulSoup(source_code_from_URL, 'lxml', from_encoding='utf-8')
    text = ''
    for item in soup.find_all('div', id='articleBodyContents'):
        text = text + str(item.find_all(text=True))
    return text

# 메인 함수
def main():
    open_output_file = open(OUTPUT_FILE_NAME, 'w')
    result_text = get_text(URL)
    open_output_file.write(result_text)
    open_output_file.close()
    
 
if __name__ == '__main__':
    main()


#출처: http://yoonpunk.tistory.com/4 [윤빵꾸의 공부노트]

# %%
result_text = get_text(URL)
result_text
# Out:
# "['\\n', ' 본문 내용 ', '\\n', ' TV플레이어 ', '\\n', '\\n', '\\n', '\\n', ' // TV플레이어 ', '\\n', '\\n// flash 오류를 우회하기 위한 함수 추가\\nfunction _flash_removeCallback() {}\\n', '\\n\\t\\n\\t네, 바람이 한결 선선해졌습니다.', '그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.', '폭염이 물러가고 열대야도 대부분 해소됐습니다.', '이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.', '또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.', '지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.', '이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.', '남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.', '오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.', '주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.', '또 그리고 당분간 늦더위는 계속될 전망입니다.', '(이나영 기상캐스터)\\xa0', '※ ⓒ SBS & SBS콘텐츠허브 : 무단복제 및 재배포 금지', '☞ SBS뉴스에 영상 제보하고 상품권 받기!', '\\n', ' // 본문 내용 ', '\\n']"

# %%
txtlist = result_text.split()
print (txtlist)
print (type(result_text))
# Out:
# ["['\\n',", "'", '본문', '내용', "',", "'\\n',", "'", 'TV플레이어', "',", "'\\n',", "'\\n',", "'\\n',", "'\\n',", "'", '//', 'TV플레이어', "',", "'\\n',", "'\\n//", 'flash', '오류를', '우회하기', '위한', '함수', '추가\\nfunction', '_flash_removeCallback()', "{}\\n',", "'\\n\\t\\n\\t네,", '바람이', '한결', "선선해졌습니다.',", "'그동안", '힘들었던', '폭염이', '물러갔는데요,', '시원한', '단비가', '내린', '데다가', '찬', '공기가', '내려왔기', "때문입니다.',", "'폭염이", '물러가고', '열대야도', '대부분', "해소됐습니다.',", "'이제", '큰', '더위', '걱정은', '안', '하셔도', '되겠는데요,', '오늘(26일)', '서울의', '낮', '기온', '28도로', '정말', '모처럼', '30도', '아래로', "내려왔습니다.',", "'또", '내일과', '모레', '주말', '동안', '30도', '안팎에', '머물겠지만,', '그동안처럼', '혹독한', '폭염은', "없겠습니다.',", "'지금", '비는', '대부분', '그쳤는데요,', '주로', '충청과', '경북', '지방을', '중심으로', '비가', '내리고', "있습니다.',", "'이", '비도', '낮에는', '대부분', '그치겠고요,', '동해안은', '동풍의', '영향으로', '오후까지', '비가', '조금', "내리겠습니다.',", "'남부", '지방은', '대기', '불안정으로', '밤까지', '요란한', '소나기가', "지나겠습니다.',", "'오늘", '낮', '기온은', '서울,', '대전,', '전주', '28도,', '대구', '25도로', '어제보다', '기온이', '많게는', '10도나', '뚝', "떨어지겠습니다.',", "'주말인", '내일', '중부', '지방은', '구름만', '많겠지만,', '영동과', '남부', '지방은', '비', '소식이', '있는데요,', '내일', '밤', '비가', '시작돼', '모레까지', "이어지겠습니다.',", "'또", '그리고', '당분간', '늦더위는', '계속될', "전망입니다.',", "'(이나영", "기상캐스터)\\xa0',", "'※", 'ⓒ', 'SBS', '&', 'SBS콘텐츠허브', ':', '무단복제', '및', '재배포', "금지',", "'☞", 'SBS뉴스에', '영상', '제보하고', '상품권', "받기!',", "'\\n',", "'", '//', '본문', '내용', "',", "'\\n']"]
# <class 'str'>

# %%
for i, v in enumerate(txtlist):
    print (i, '>> ', v)
# Out:
# 0 >>  ['\n',
# 1 >>  '
# 2 >>  본문
# 3 >>  내용
# 4 >>  ',
# 5 >>  '\n',
# 6 >>  '
# 7 >>  TV플레이어
# 8 >>  ',
# 9 >>  '\n',
# 10 >>  '\n',
# 11 >>  '\n',
# 12 >>  '\n',
# 13 >>  '
# 14 >>  //
# 15 >>  TV플레이어
# 16 >>  ',
# 17 >>  '\n',
# 18 >>  '\n//
# 19 >>  flash
# 20 >>  오류를
# 21 >>  우회하기
# 22 >>  위한
# 23 >>  함수
# 24 >>  추가\nfunction
# 25 >>  _flash_removeCallback()
# 26 >>  {}\n',
# 27 >>  '\n\t\n\t네,
# 28 >>  바람이
# 29 >>  한결
# 30 >>  선선해졌습니다.',
# 31 >>  '그동안
# 32 >>  힘들었던
# 33 >>  폭염이
# 34 >>  물러갔는데요,
# 35 >>  시원한
# 36 >>  단비가
# 37 >>  내린
# 38 >>  데다가
# 39 >>  찬
# 40 >>  공기가
# 41 >>  내려왔기
# 42 >>  때문입니다.',
# 43 >>  '폭염이
# 44 >>  물러가고
# 45 >>  열대야도
# 46 >>  대부분
# 47 >>  해소됐습니다.',
# 48 >>  '이제
# 49 >>  큰
# 50 >>  더위
# 51 >>  걱정은
# 52 >>  안
# 53 >>  하셔도
# 54 >>  되겠는데요,
# 55 >>  오늘(26일)
# 56 >>  서울의
# 57 >>  낮
# 58 >>  기온
# 59 >>  28도로
# 60 >>  정말
# 61 >>  모처럼
# 62 >>  30도
# 63 >>  아래로
# 64 >>  내려왔습니다.',
# 65 >>  '또
# 66 >>  내일과
# 67 >>  모레
# 68 >>  주말
# 69 >>  동안
# 70 >>  30도
# 71 >>  안팎에
# 72 >>  머물겠지만,
# 73 >>  그동안처럼
# 74 >>  혹독한
# 75 >>  폭염은
# 76 >>  없겠습니다.',
# 77 >>  '지금
# 78 >>  비는
# 79 >>  대부분
# 80 >>  그쳤는데요,
# 81 >>  주로
# 82 >>  충청과
# 83 >>  경북
# 84 >>  지방을
# 85 >>  중심으로
# 86 >>  비가
# 87 >>  내리고
# 88 >>  있습니다.',
# 89 >>  '이
# 90 >>  비도
# 91 >>  낮에는
# 92 >>  대부분
# 93 >>  그치겠고요,
# 94 >>  동해안은
# 95 >>  동풍의
# 96 >>  영향으로
# 97 >>  오후까지
# 98 >>  비가
# 99 >>  조금
# 100 >>  내리겠습니다.',
# 101 >>  '남부
# 102 >>  지방은
# 103 >>  대기
# 104 >>  불안정으로
# 105 >>  밤까지
# 106 >>  요란한
# 107 >>  소나기가
# 108 >>  지나겠습니다.',
# 109 >>  '오늘
# 110 >>  낮
# 111 >>  기온은
# 112 >>  서울,
# 113 >>  대전,
# 114 >>  전주
# 115 >>  28도,
# 116 >>  대구
# 117 >>  25도로
# 118 >>  어제보다
# 119 >>  기온이
# 120 >>  많게는
# 121 >>  10도나
# 122 >>  뚝
# 123 >>  떨어지겠습니다.',
# 124 >>  '주말인
# 125 >>  내일
# 126 >>  중부
# 127 >>  지방은
# 128 >>  구름만
# 129 >>  많겠지만,
# 130 >>  영동과
# 131 >>  남부
# 132 >>  지방은
# 133 >>  비
# 134 >>  소식이
# 135 >>  있는데요,
# 136 >>  내일
# 137 >>  밤
# 138 >>  비가
# 139 >>  시작돼
# 140 >>  모레까지
# 141 >>  이어지겠습니다.',
# 142 >>  '또
# 143 >>  그리고
# 144 >>  당분간
# 145 >>  늦더위는
# 146 >>  계속될
# 147 >>  전망입니다.',
# 148 >>  '(이나영
# 149 >>  기상캐스터)\xa0',
# 150 >>  '※
# 151 >>  ⓒ
# 152 >>  SBS
# 153 >>  &
# 154 >>  SBS콘텐츠허브
# 155 >>  :
# 156 >>  무단복제
# 157 >>  및
# 158 >>  재배포
# 159 >>  금지',
# 160 >>  '☞
# 161 >>  SBS뉴스에
# 162 >>  영상
# 163 >>  제보하고
# 164 >>  상품권
# 165 >>  받기!',
# 166 >>  '\n',
# 167 >>  '
# 168 >>  //
# 169 >>  본문
# 170 >>  내용
# 171 >>  ',
# 172 >>  '\n']

# %%
import re # regular expression

# %% [markdown]
# ### 영어철자 및 특수 문자 제거

# %%
txt_wo_eng = re.sub( '[a-zA-Z]', '', result_text) # 영어 알파벳 제거

# %%
txt_clean = re.sub ('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]','', txt_wo_eng)

# %%
txt_clean
# Out:
# '  본문 내용    플레이어        플레이어     오류를 우회하기 위한 함수 추가   네 바람이 한결 선선해졌습니다 그동안 힘들었던 폭염이 물러갔는데요 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다 폭염이 물러가고 열대야도 대부분 해소됐습니다 이제 큰 더위 걱정은 안 하셔도 되겠는데요 오늘26일 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다 또 내일과 모레 주말 동안 30도 안팎에 머물겠지만 그동안처럼 혹독한 폭염은 없겠습니다 지금 비는 대부분 그쳤는데요 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다 이 비도 낮에는 대부분 그치겠고요 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다 남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다 오늘 낮 기온은 서울 대전 전주 28도 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다 주말인 내일 중부 지방은 구름만 많겠지만 영동과 남부 지방은 비 소식이 있는데요 내일 밤 비가 시작돼 모레까지 이어지겠습니다 또 그리고 당분간 늦더위는 계속될 전망입니다 이나영 기상캐스터0 ※ ⓒ   콘텐츠허브  무단복제 및 재배포 금지 ☞ 뉴스에 영상 제보하고 상품권 받기    본문 내용  '

# %% [markdown]
# ### 영어 알파벳 제거하지 않은 경우

# %%
txt_1 = re.sub ('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]','', result_text)
txt_1
# Out:
# 'n  본문 내용  n  TV플레이어  n n n n   TV플레이어  n n flash 오류를 우회하기 위한 함수 추가nfunction flashremoveCallback n ntnt네 바람이 한결 선선해졌습니다 그동안 힘들었던 폭염이 물러갔는데요 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다 폭염이 물러가고 열대야도 대부분 해소됐습니다 이제 큰 더위 걱정은 안 하셔도 되겠는데요 오늘26일 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다 또 내일과 모레 주말 동안 30도 안팎에 머물겠지만 그동안처럼 혹독한 폭염은 없겠습니다 지금 비는 대부분 그쳤는데요 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다 이 비도 낮에는 대부분 그치겠고요 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다 남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다 오늘 낮 기온은 서울 대전 전주 28도 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다 주말인 내일 중부 지방은 구름만 많겠지만 영동과 남부 지방은 비 소식이 있는데요 내일 밤 비가 시작돼 모레까지 이어지겠습니다 또 그리고 당분간 늦더위는 계속될 전망입니다 이나영 기상캐스터xa0 ※ ⓒ SBS  SBS콘텐츠허브  무단복제 및 재배포 금지 ☞ SBS뉴스에 영상 제보하고 상품권 받기 n   본문 내용  n'

# %% [markdown]
# ### New line character & tab character 제거 ('\n', '\t')

# %%
txt_2 = re.sub ('\\\\n|\\\\t', '', result_text)
txt_2
# Out:
# "['', ' 본문 내용 ', '', ' TV플레이어 ', '', '', '', '', ' // TV플레이어 ', '', '// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}', '네, 바람이 한결 선선해졌습니다.', '그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.', '폭염이 물러가고 열대야도 대부분 해소됐습니다.', '이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.', '또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.', '지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.', '이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.', '남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.', '오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.', '주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.', '또 그리고 당분간 늦더위는 계속될 전망입니다.', '(이나영 기상캐스터)\\xa0', '※ ⓒ SBS & SBS콘텐츠허브 : 무단복제 및 재배포 금지', '☞ SBS뉴스에 영상 제보하고 상품권 받기!', '', ' // 본문 내용 ', '']"

# %%
txt2list = txt_2.split('\'')
print(txt2list[10])
txt2list
# Out:
# ,
# ['[',
#  '',
#  ', ',
#  ' 본문 내용 ',
#  ', ',
#  '',
#  ', ',
#  ' TV플레이어 ',
#  ', ',
#  '',
#  ', ',
#  '',
#  ', ',
#  '',
#  ', ',
#  '',
#  ', ',
#  ' // TV플레이어 ',
#  ', ',
#  '',
#  ', ',
#  '// flash 오류를 우회하기 위한 함수 추가function _flash_removeCallback() {}',
#  ', ',
#  '네, 바람이 한결 선선해졌습니다.',
#  ', ',
#  '그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.',
#  ', ',
#  '폭염이 물러가고 열대야도 대부분 해소됐습니다.',
#  ', ',
#  '이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.',
#  ', ',
#  '또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.',
#  ', ',
#  '지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.',
#  ', ',
#  '이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.',
#  ', ',
#  '남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.',
#  ', ',
#  '오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.',
#  ', ',
#  '주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.',
#  ', ',
#  '또 그리고 당분간 늦더위는 계속될 전망입니다.',
#  ', ',
#  '(이나영 기상캐스터)\\xa0',
#  ', ',
#  '※ ⓒ SBS & SBS콘텐츠허브 : 무단복제 및 재배포 금지',
#  ', ',
#  '☞ SBS뉴스에 영상 제보하고 상품권 받기!',
#  ', ',
#  '',
#  ', ',
#  ' // 본문 내용 ',
#  ', ',
#  '',
#  ']']

# %% [markdown]
# ## 크롤링할 때 soup 데이터에서 찾아주는 문장을 list 타입으로 바로 받을 수 있다.

# %%
# 크롤링 함수 2
source_code_from_URL = urllib.request.urlopen(URL)

# %%
soup = BeautifulSoup(source_code_from_URL, 'lxml', from_encoding='utf-8')

# %%
soup
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1023" name="viewport"/>
# <title>[날씨] 한결 선선해진 바람…주말 30도 안팎 : 네이버 뉴스</title>
# <meta content="SBS 뉴스 : 네이버뉴스" property="me2:post_tag"/>
# <meta content="SBS 뉴스" property="me2:category1"/>
# <meta content="생활/문화" property="me2:category2"/>
# <meta content="http://imgnews.naver.net/image/origin/055/2016/08/26/445667.jpg" property="me2:image"/>
# <meta content="[날씨] 한결 선선해진 바람…주말 30도 안팎" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;oid=055&amp;aid=0000445667&amp;sid1=001" property="og:url"/>
# <meta content="http://imgnews.naver.net/image/origin/055/2016/08/26/445667.jpg" property="og:image"/>
# <meta content="네, 바람이 한결 선선해졌습니다.그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.폭염이 물러가고 열대야도 대부분 해소됐습니다.이제 큰 ..." property="og:description"/>
# <meta content="SBS 뉴스 | 네이버 뉴스" property="og:article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="[날씨] 한결 선선해진 바람…주말 30도 안팎" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="SBS 뉴스" name="twitter:creator"/>
# <meta content="http://imgnews.naver.net/image/origin/055/2016/08/26/445667.jpg" name="twitter:image"/>
# <meta content="네, 바람이 한결 선선해졌습니다.그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.폭염이 물러가고 열대야도 대부분 해소됐습니다.이제 큰 ..." name="twitter:description"/>
# <link href="http://static.news.naver.net/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link charset="euc-kr" href="http://static.news.naver.net/pnews/resources/20171227_215918/css/common.css" rel="stylesheet" type="text/css"/>
# <link charset="euc-kr" href="http://static.news.naver.net/pnews/resources/20171227_215918/css/news.css" rel="stylesheet" type="text/css"/>
# <link href="http://static.news.naver.net/pnews/resources/20171227_215918/css/dic_tooltip.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="http://static.news.naver.net/pnews/resources/20171227_215918/js/news.jindo.js" type="text/javascript"></script>
# <script type="text/javascript">
# document.domain='naver.com';
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var nsc='news.life';
# var gnb_service='news';
# var gnb_logout='http://news.naver.com';
# var gnb_template='gnb_euckr';
# var gnb_brightness = 1;
# var gnb_one_naver = 1;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue Jan 09 21:51:24 KST 2018";
# </script>
# <script charset="euc-kr" src="http://static.news.naver.net/pnews/resources/20171227_215918/js/news.service.js" type="text/javascript"></script>
# <script charset="utf-8" src="http://static.news.naver.net/pnews/resources/20171227_215918/js/dic.tooltip.js" type="text/javascript"></script>
# <script charset="utf-8" src="http://static.news.naver.net/pnews/resources/20171227_215918/js/nil.news.js" type="text/javascript"></script>
# <meta content="IE=9; IE=8; IE=7" http-equiv="X-UA-Compatible"/>
# </head>
# <body>
# <div id="wrap">
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div id="header">
# <!-- Skip navigation -->
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#snb" tabindex="2"><span>서브 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="3"><span>본문으로 바로가기</span></a>
# </div>
# <!-- //Skip navigation -->
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_wrap">
# <!-- GNB 마크업 -->
# <div id="gnb"></div>
# <!-- //GNB 마크업 -->
# </div>
# <div id="snb_wrap">
# <h1><a class="h_logo nclicks(STA.naver)" href="http://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(STA.news)" href="http://news.naver.com/"><span class="blind">뉴스</span></a> </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="nclicks(STA.enter)" href="http://entertain.naver.com/home"><img alt="TV연예" height="19" src="http://static.news.naver.net/image/news/2017/10/snb_h_entertain.png" width="52"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.sports)" href="http://sports.news.naver.com"><img alt="스포츠" height="19" src="http://static.news.naver.net/image/news/2017/10/snb_h_sports.png" width="48"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.newsstand)" href="http://newsstand.naver.com"><img alt="뉴스스탠드" height="19" src="http://static.news.naver.net/image/news/2017/10/snb_h_newsstand.png" width="77"/></a></li>
# <li><span class="snb_bdr"></span><a class="nclicks(STA.weather)" href="http://weather.naver.com"><img alt="날씨" height="19" src="http://static.news.naver.net/image/news/2017/10/snb_h_weather.png" width="31"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="m1 nclicks(LNB.home)" href="/main/home.nhn"><span class="tx"><span class="blind">뉴스홈</span></span> </a></li>
# <li><a class="m2 nclicks(LNB.flash)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=001"><span class="tx"><span class="blind">속보</span></span> </a></li>
# <li><a class="m3 nclicks(LNB.pol)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx"><span class="blind">정치</span></span> </a></li>
# <li><a class="m4 nclicks(LNB.eco)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx"><span class="blind">경제</span></span> </a></li>
# <li><a class="m5 nclicks(LNB.soc)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx"><span class="blind">사회</span></span> </a></li>
# <li class="on"><a class="m6 nclicks(LNB.lif)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx"><span class="blind">생활/문화</span></span> <span class="blind">선택됨</span></a></li>
# <li><a class="m7 nclicks(LNB.wor)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx"><span class="blind">세계</span></span> </a></li>
# <li><a class="m8 nclicks(LNB.sci)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx"><span class="blind">IT/과학</span></span> </a></li>
# <li><a class="m9 nclicks(LNB.opi)" href="/main/opinion/home.nhn"><span class="tx"><span class="blind">오피니언</span></span> </a></li>
# <li><a class="m10 nclicks(LNB.pho)" href="/main/photo/index.nhn?mid=pho"><span class="tx"><span class="blind">포토</span></span> </a></li>
# <li><a class="m11 nclicks(LNB.tv)" href="/main/tv/index.nhn?mid=tvh"><span class="tx"><span class="blind">TV</span></span> </a></li>
# <li><a class="m12 nclicks(LNB.ranking)" href="/main/ranking/popularDay.nhn?mid=etc&amp;sid1=111"><span class="tx"><span class="blind">랭킹뉴스</span></span> </a></li>
# </ul>
# <form accept-charset="UTF-8" action="https://search.naver.com/search.naver" id="lnb.searchForm" method="get" name="lnb_searchForm" target="_blank">
# <fieldset>
# <legend>뉴스 검색</legend>
# <input accesskey="s" class="text_index" name="query" style="ime-mode:active;" title="뉴스 검색" type="text"/>
# <input name="where" type="hidden" value="news"/>
# <input name="ie" type="hidden" value="utf8"/>
# <input name="sm" type="hidden" value="nws_hty"/>
# <button class="btn_search_lnb nclicks(LNB.search)" type="submit"><span class="tx"><span class="blind">검색</span></span></button>
# </fieldset>
# </form>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>01</strong>.<strong>09</strong><span class="day">(화)</span></span>
# <div class="lnb_weather" id="lnb.weather" title="서울 -5 °C
# 인천 -4 °C
# 수원 -3 °C
# 대전 -2 °C
# 청주 -3 °C
# 강릉 -3 °C
# 춘천 -5 °C
# 광주 0 °C
# 전주 -1 °C
# 부산 1 °C
# 대구 -1 °C
# 제주 5 °C
# 울산 0 °C
# 울릉도 0 °C">
# <h3 class="blind">날씨정보</h3><ul>
# <li><a class="nclicks(nct.weather,,1)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT001013"><img alt="흐림" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s3.gif" title="흐림" width="36"/>서울<span><em>-5</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,2)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT001028"><img alt="흐림" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s3.gif" title="흐림" width="36"/>인천<span><em>-4</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,3)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT001015"><img alt="흐림" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s3.gif" title="흐림" width="36"/>수원<span><em>-3</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,4)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT006005"><img alt="보통눈계속" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s5.gif" title="보통눈계속" width="36"/>대전<span><em>-2</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,5)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT005010"><img alt="약한눈계속" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s5.gif" title="약한눈계속" width="36"/>청주<span><em>-3</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,6)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT004001"><img alt="구름조금" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s2.gif" title="구름조금" width="36"/>강릉<span><em>-3</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,7)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT003007"><img alt="맑음" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s1.gif" title="맑음" width="36"/>춘천<span><em>-5</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,8)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT011005"><img alt="소낙눈 끝" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s19.gif" title="소낙눈 끝" width="36"/>광주<span><em>0</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,9)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT010011"><img alt="소낙눈" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s8.gif" title="소낙눈" width="36"/>전주<span><em>-1</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,10)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT008008"><img alt="맑음" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s1.gif" title="맑음" width="36"/>부산<span><em>1</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,11)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT007007"><img alt="맑음" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s1.gif" title="맑음" width="36"/>대구<span><em>-1</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,12)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT012005"><img alt="진눈깨비 끝" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s19.gif" title="진눈깨비 끝" width="36"/>제주<span><em>5</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,13)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT008012"><img alt="맑음" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s1.gif" title="맑음" width="36"/>울산<span><em>0</em>°C</span></a></li>
# <li><a class="nclicks(nct.weather,,14)" href="http://weather.naver.com/rgn/cityWetrCity.nhn?cityRgnCd=CT009002"><img alt="구름많음" height="26" src="https://ssl.pstatic.net/static/weather/images/w_icon/w_s21.gif" title="구름많음" width="36"/>울릉도<span><em>0</em>°C</span></a></li>
# </ul>
# </div>
# <div class="lnb_today">
# <h3><a class="nclicks(nct.main)" href="http://news.naver.com/main/history/mainnews/index.nhn" title="이 시각 주요뉴스 배열 이력">주요뉴스</a></h3>
# <div id="lnb.mainnews">
# <ul>
# <li>
# <a class="nclicks(nct.maintxt,,1)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0009801535" title="남북, 北대표단 평창 파견·군사당국회담 개최 합의">남북, 北대표단 평창 파견·군사당국회담 개최 합의</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,2)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0009801392" title="판문점채널 이어 軍통신선도 복원…남북 상시협의 가능">판문점채널 이어 軍통신선도 복원…남북 상시협의 가능</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,3)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=022&amp;aid=0003240719" title=" 합의 파기·재협상 대신 '무력화'… 日에 진정한 사과 촉구"> 합의 파기·재협상 대신 '무력화'… 日에 진정한 사과 …</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,4)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0008384510" title='文대통령 "바라카 원전, 한·UAE 관계 상징···준공 전이라도 방문"'>文대통령 "바라카 원전, 한·UAE 관계 상징···준공 …</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,5)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=052&amp;aid=0001103924" title="밤사이 전국 눈 확대…내일 오늘보다 더 추워">밤사이 전국 눈 확대…내일 오늘보다 더 추워</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,6)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=003&amp;aid=0008384569" title="2018 주요대학 정시 경쟁률↑…연대 5.33대 1·고대 5.36대 1">2018 주요대학 정시 경쟁률↑…연대 5.33대 1·고대 5.36…</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,7)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=103&amp;oid=028&amp;aid=0002394081" title=' 고양시 "구석기 유물 출토" 성급한 발표 논란 '> 고양시 "구석기 유물 출토" 성급한 발표 논란 </a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,8)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0003141042" title="경찰, 여고생 감금·폭행 피의자 4명 구속영장">경찰, 여고생 감금·폭행 피의자 4명 구속영장</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,9)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=056&amp;aid=0010535256" title="'고래고기' 놓고 5개월째 검·경 충돌, 진실은?">'고래고기' 놓고 5개월째 검·경 충돌, 진실은?</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,10)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=449&amp;aid=0000145525" title="향수 뿌리다 불 날라…화재에 취약한 생활용품">향수 뿌리다 불 날라…화재에 취약한 생활용품</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,11)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=448&amp;aid=0000232092" title="북한, 응원단·예술단·태권도단 보낸다">북한, 응원단·예술단·태권도단 보낸다</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,12)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=001&amp;aid=0009801529" title="강릉 다가구 주택서 LP가스 폭발…12명 부상">강릉 다가구 주택서 LP가스 폭발…12명 부상</a>
# </li>
# <li>
# <a class="nclicks(nct.maintxt,,13)" href="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=020&amp;aid=0003120508" title="'北 공작원 중국 내 거점' 칠보산호텔, 9일 전격 폐쇄">'北 공작원 중국 내 거점' 칠보산호텔, 9일 전격 폐쇄</a>
# </li>
# </ul>
# </div>
# </div>
# <ul class="lnb_side" tabindex="0">
# <li>
# <a class="nclicks(nct.right1)" href="http://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;cid=1019690" title="상식in뉴스">상식in뉴스
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right2)" href="http://news.naver.com/main/officeList.nhn" title="언론사 뉴스">언론사 뉴스
# </a>
# </li>
# <li>
# <a class="nclicks(nct.right3)" href="http://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리
# </a>
# </li>
# <li class="end">
# <a class="nclicks(nct.right4)" href="http://news.naver.com/main/history/mainnews/index.nhn" title="이 시각 주요뉴스 배열 이력">기사배열 이력
# </a>
# </li>
# </ul>
# </div>
# </div>
# <hr/>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사본문</caption>
# <colgroup>
# <col width="87"/>
# <col/>
# <col width="280"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h5"><a class="nclicks(lmn_lif.home)" href="/main/main.nhn?mode=LSD&amp;mid=shm&amp;sid1=103">생활/문화</a></h2>
# <ul class="nav">
# <li><a class="snb_s35 nclicks(lmn_lif.mnl,,1)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=241">건강정보 </a></li>
# <li><a class="snb_s36 nclicks(lmn_lif.mnl,,2)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=239">자동차/시승기 </a></li>
# <li><a class="snb_s100 nclicks(lmn_lif.mnl,,3)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=240">도로/교통 </a></li>
# <li><a class="snb_s37 nclicks(lmn_lif.mnl,,4)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=237">여행/레저 </a></li>
# <li><a class="snb_s38 nclicks(lmn_lif.mnl,,5)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=238">음식/맛집 </a></li>
# <li><a class="snb_s101 nclicks(lmn_lif.mnl,,6)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=376">패션/뷰티 </a></li>
# <li><a class="snb_s40 nclicks(lmn_lif.mnl,,7)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=242">공연/전시 </a></li>
# <li><a class="snb_s105 nclicks(lmn_lif.mnl,,8)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=243">책 </a></li>
# <li><a class="snb_s106 nclicks(lmn_lif.mnl,,9)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=244">종교 </a></li>
# <li><a class="snb_s39 nclicks(lmn_lif.mnl,,10)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=248">날씨 </a></li>
# <li><a class="snb_s34 nclicks(lmn_lif.mnl,,11)" href="/main/list.nhn?mode=LS2D&amp;mid=shm&amp;sid1=103&amp;sid2=245">생활문화 일반 </a></li>
# <li><a class="snb_s18 nclicks(lmn_lif.fla)" href="/main/list.nhn?mode=LSD&amp;mid=sec&amp;sid1=103">속보 </a></li>
# </ul>
# <div class="snb_banner"><a class="nclicks(lmn_lif.pmb,,1)" href="http://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;gid=1073392&amp;cid=1073394"><img alt="이달의 방송기자상" height="74" src="http://imgnews.naver.net/image/upload/item/2013/12/30/142128495_banner_01.png" width="71"/></a></div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <script type="text/javascript">
# 	if (nil) {
# 		nil.init('naver_news', '055');
#
# 		nil.add({
# 			'uri': 'http://news.naver.com/main/read.nhn?oid=055&aid=0000445667',
# 			'dimension_1': '%EC%83%9D%ED%99%9C'
#
# 		});
# 		//cv 측정
# 		nil.send('cv', 'post_view');
#
# 		if (window.attachEvent) {
# 			window.attachEvent("onunload", function() {nil.send('leave');});
# 		} else if (window.addEventListener) {
# 			window.addEventListener("unload", function() {nil.send('leave');}, false);
# 		} else {
# 			var fnOnUnload = window.onunload;
# 			window.onunload = function() {
# 				nil.send('leave');
#                 fnOnUnload();
# 			};
# 		}
# 	}
# </script>
# <script type="text/javascript">
# if (typeof window.ReadingObserver !== 'undefined') {
# 	ReadingObserver.start('articleBody', {
# 	sContentBottomId : 'spiLayer',
# 	oid : '055',
# 	aid : '0000445667',
# 	sid : '103',
# 	articleType : '2',
# 	hitRefererType : 'UNKNOWN',
# 	gdid : '8800011C_000000000000000000445667'
# 	});
# }
# </script>
# <!-- test -->
# <div class="article_ctrl">
# <div class="font_setup">
# <div class="button">
# <button alt="글꼴" class="font_f" id="read_fontButton" style="cursor:pointer" title="글꼴" type="button"><span>글꼴 선택</span></button>
# <div class="layer01" id="read.fontLayer">
# <div class="shadow"></div>
# <ul class="layer01_content" id="fontLayoutSelectbox"></ul>
# </div>
# </div>
# <div class="button"><button class="fs_small" style="cursor:pointer" title="축소"><span>본문 텍스트 작게</span></button><button class="fs_big" style="cursor:pointer" title="확대"><span>본문 텍스트 크게</span></button></div>
# </div>
# <ul class="content_menu">
# <li><a class="scrap" href="/main/scrap/folderList.nhn?scrapItem.officeId=055&amp;scrapItem.articleId=0000445667" target="_blank" title="스크랩">스크랩</a></li>
# <li class="first"><a class="print" href="/main/tool/print.nhn?oid=055&amp;aid=0000445667" target="_blank">인쇄</a></li>
# </ul>
# </div>
# <!-- 기사 헤더 -->
# <div class="article_header">
# <div class="press_logo">
# <a href="http://news.sbs.co.kr/" target="_blank">
# <img alt="SBS 뉴스" class="" height="40" src="http://mimgnews1.naver.net/image/upload/office_logo/055/2017/01/05/logo_055_11_20170105110805.gif" title="SBS 뉴스" width="85"/>
# </a>
# <span class="vline"></span>
# </div>
# <div class="article_info">
# <h3 class="font1" id="articleTitle">[날씨] 한결 선선해진 바람…주말 30도 안팎</h3>
# <!-- 영문뉴스 듣기 -->
# <div class="tts_svc">
# <!-- [D] 국문기사 경우 : tts 아이콘 클릭했을때 .tts_voice 에 on 클래스를 추가해주세요. / on 일때 대체텍스트 '듣는중..'으로 변경 -->
# <!-- [D] 영문기사 경우 : 버튼 클릭시 .tts_popup 팝업레이어 display:block 처리 -->
# <button class="tts_voice nclicks(ats.tts)" title="영문뉴스 음성지원 서비스" type="button">
# <span class="tts_voice_ico">영문 뉴스 음성지원 서비스 듣기</span>
# <span class="tts_voice_txt">본문듣기</span>
# </button>
# <i class="tts_bar"></i>
# <button class="tts_setting nclicks(ats.ttsop)" title="텍스트 음성 변환 설정" type="button">
# <span class="tts_setting_ico"></span>
# <span class="tts_setting_txt">설정</span>
# </button>
# <div class="tts_popup " style="display: none;">
# <div class="tts_spd_select _tts_gender_select">
# <span class="blind">성별 선택하기</span>
# <!-- [D] 선택 : <span class="spd_btn--on">선택된 속도</span> 추가 -->
# <a class="_gender_btn nclicks(ats.ttsfe)" data-value="f" href="#" id="gender_sel_f"><span class="spd_btn"></span>여성</a>
# <a class="_gender_btn nclicks(ats.ttsma)" data-value="m" href="#" id="gender_sel_m"><span class="spd_btn spd_btn--on">선택된 성별</span>남성</a>
# </div>
# <i class="tts_spd_bar"></i>
# <div class="tts_spd_select _tts_spd_select">
# <span class="blind">속도 선택하기</span>
# <!-- [D] 선택 : <span class="spd_btn--on">선택된 속도</span> 추가 -->
# <a class="_spdbar_btn nclicks(ats.ttssp)" data-value="3" href="#" id="speed_sel3"><span class="spd_btn"></span>느림</a>
# <a class="_spdbar_btn nclicks(ats.ttssp)" data-value="2" href="#" id="speed_sel2"><span class="spd_btn spd_btn--on">선택된 속도</span>보통</a>
# <a class="_spdbar_btn nclicks(ats.ttssp)" data-value="0" href="#" id="speed_sel0"><span class="spd_btn"></span>빠름</a>
# </div>
# <div class="tts_save">
# <p class="tts_save__text">설정을 저장하시겠습니까?</p>
# <a class="tts_save__btn _spd_save_btn nclicks(ats.ttsok)" href="#">확인</a>
# <a class="tts_save__btn _spd_cancel_btn nclicks(ats.ttscancel)" href="#">취소</a>
# </div>
# </div>
# </div>
# <div id="tts_player_div" style="display:none;"></div>
# <script type="text/javascript">
# 	var ttsPlayer = new nhn.NewsTTSPlayer({
# 		sOfficeId	:'055',
# 		sArticleId	:'0000445667',
# 		sNationText : 'ko'
# 	});
# 	</script>
# <div class="sponsor">
# <!-- 기사 헤더 > 정보 -->
#
#
#
#
# 기사입력 <span class="t11">2016-08-26 12:54</span>
# <!-- // 기사 헤더 > 정보 -->
# <a class="btn_artialoriginal nclicks(are.ori,'055', 'nilGParam', '055_ba674da8303261e8')" href="http://news.sbs.co.kr/news/endPage.do?news_id=N1003752467&amp;plink=ORI&amp;cooper=NAVER" target="_blank">기사원문</a>
# <div class="article_btns">
# <div class="_reactionModule u_likeit" data-cid="ne_055_0000445667" data-sid="NEWS" style="visibility: hidden">
# <a aria-haspopup="true" aria-pressed="false" class="u_likeit_button _face" data-label="news" href="#" onclick="nclk(this,'RTL.face','','');return false;">
# <span class="u_likeit_icons _icons">
# <span class="u_likeit_icon __reaction__like"><span class="u_likeit_blind">좋아요</span></span>
# </span>
# <span class="u_likeit_blind">좋아요 평가하기</span>
# <span class="u_likeit_text _count">공감</span>
# </a>
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list good" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.like|RTL.unlike" data-type="like" href="#" role="button">
# <span class="u_likeit_list_name _label">좋아요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list warm" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.warm|RTL.unwarm" data-type="warm" href="#" role="button">
# <span class="u_likeit_list_name _label">훈훈해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list sad" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.sad|RTL.unsad" data-type="sad" href="#" role="button">
# <span class="u_likeit_list_name _label">슬퍼요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list angry" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.angry|RTL.unangry" data-type="angry" href="#" role="button">
# <span class="u_likeit_list_name _label">화나요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTL.want|RTL.unwant" data-type="want" href="#" role="button">
# <span class="u_likeit_list_name _label">후속기사 원해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# <a class="pi_btn_count nclicks(atp.reply)" href="#" id="articleTitleCommentCount">
# <span class="lo_txt"></span>
# </a>
# <div class="sns_share">
# <a class="naver-splugin" data-band-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=blog" data-cafe-source-type="3" data-cafe-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=cafe" data-calendar-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=calendar" data-facebook-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=facebook" data-likecontentsid="ne_055_0000445667" data-likeserviceid="NEWS" data-mail-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=mail" data-me-display="off" data-memo-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=memo" data-style="unity" data-title="[날씨] 한결 선선해진 바람…주말 30도 안팎" data-twitter-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=twitter" data-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667" href="#"><span class="naver-splugin-c sns_share_ico"></span></a>
# </div>
# <div class="head_channel" style="display: none;">
# <button class="head_channel_button" type="button">
# <i class="head_channel_pick">PICK</i>
# <i class="head_channel_info">안내</i>
# </button>
# <p class="head_channel_layer" style="display: none;">
# <span class="head_channel_layer_text">해당 언론사가 채널 주요 뉴스로<br/>직접 선정한 기사입니다.</span>
# <a class="head_channel_layer_link" href="http://news.naver.com/main/static/channelPromotion.html" target="_blank">채널 안내</a>
# <button class="head_channel_layer_close" type="button">닫기</button>
# </p>
# </div>
# <script type="text/javascript">
#     jindo.$Fn(function() {
#         var params = getLocationQueryParams();
#         var url = "/main/ajax/channel/isPickedArticle.nhn?oid=" + params.oid + "&aid=" + params.aid;
#         var oAjax = jindo.$Ajax(url, {
#             method: "get",
#             onload: function (res) {
#                 var isPicked;
#                 try {
#                     isPicked = res.json();
#                 } catch (e) {
#                     return;
#                 }
#
#                 if (!isPicked) {
#                     return;
#                 }
#
#                 initChannelPickBanner();
#             }
#         });
#
#         oAjax.request();
#
#         function initChannelPickBanner() {
#             var welHeadTop = jindo.$ElementList(".article_header").getFirst();
#             var welLogo = jindo.$Element(welHeadTop.query(".head_channel"));
#             var welLayer = jindo.$Element(welLogo.query(".head_channel_layer"));
#             var welChannelPickBannerBtn = jindo.$Element(welLogo.query(".head_channel_button"));
#             var layerAutoCloseManager = LayerAutoCloseManager.get_instance();
#
#             var layerForAutoCloseMananger = {
#                 close: function(){
#                     welLayer.hide();
#                 },
#                 isAutoCloseExceptionEl: function(el){
#                     // toggle button일 경우 예외
#                     return (welChannelPickBannerBtn.$value() === el) || welChannelPickBannerBtn.isParentOf(el);
#                 }
#             };
#
#             jindo.$Fn(function (evt) {
#                 welLayer.toggle();
#
#                 // open 이라면 적용
#                 if(welLayer.visible()){
#                     layerAutoCloseManager.setCurrentVisibleLayer(layerForAutoCloseMananger);
#                 }
#             }).attach(welChannelPickBannerBtn, "click");
#
#             jindo.$Fn(function (evt) {
#                 var wel = jindo.$Element(evt.currentElement);
#                 evt.stop();
#                 window.open(wel.attr("href"), "", "width=460, height=496");
#             }).attach(jindo.$Element(welLayer.query(".head_channel_layer_link")), "click");
#
#             welLogo.show();
#         }
#
#         function getLocationQueryParams() {
#             var params = {};
#             var kv = [];
#             var queryString = location.search.substr(1);
#             var paramStrList;
#             if (queryString) {
#                 paramStrList = queryString.split("&");
#                 for (var i = 0, len = paramStrList.length; i < len; i++) {
#                     kv = paramStrList[i].split("=");
#                     params[kv[0]] = kv[1];
#                 }
#             }
#
#             return params;
#         }
#     }).attach(window, "load");
# </script>
# </div>
# </div>
# </div>
# </div>
# <!-- // 기사 헤더 -->
# <div class="article_body font1 size4" id="articleBody">
# <!-- 본문 內 광고 -->
# <!-- // 본문 內 광고 -->
# <div id="articleBodyContents">
# <!-- 본문 내용 -->
# <!-- TV플레이어 -->
# <div class="vod_area">
# <iframe _src="/main/readVod.nhn?oid=055&amp;aid=0000445667&amp;foreignPlayVod=true" allowfullscreen="" frameborder="0" height="342" marginheight="0" marginwidth="0" title="영상 플레이어" width="544"></iframe>
# </div>
# <!-- // TV플레이어 -->
# <script type="text/javascript">
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
# </script>
#
# 	네, 바람이 한결 선선해졌습니다.<br/><br/>그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.<br/><br/>폭염이 물러가고 열대야도 대부분 해소됐습니다.<br/><br/>이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.<br/><br/>또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.<br/><br/>지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.<br/><br/>이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.<br/><br/>남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.<br/><br/>오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.<br/><br/>주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.<br/><br/>또 그리고 당분간 늦더위는 계속될 전망입니다.<br/><br/>(이나영 기상캐스터) <br/><br/><br/><br/><p>※ ⓒ SBS &amp; SBS콘텐츠허브 : 무단복제 및 재배포 금지<br/><a href="http://news.sbs.co.kr/news/inform.do?plink=FOOT&amp;cooper=NAVER">☞ SBS뉴스에 영상 제보하고 상품권 받기!</a></p>
# <!-- // 본문 내용 -->
# </div>
# <!-- 소셜플러그인 -->
# <div class="end_btn" id="spiLayer">
# <!-- 좋아요  u_likeit_module -->
# <div class="_reactionModule u_likeit" data-cid="ne_055_0000445667" data-sid="NEWS" style="visibility: hidden">
# <ul class="u_likeit_layer _faceLayer" role="menu">
# <li class="u_likeit_list good" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTC.like|RTC.unlike" data-type="like" href="#" role="button">
# <span class="u_likeit_list_name _label">좋아요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list warm" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTC.warm|RTC.unwarm" data-type="warm" href="#" role="button">
# <span class="u_likeit_list_name _label">훈훈해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list sad" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTC.sad|RTC.unsad" data-type="sad" href="#" role="button">
# <span class="u_likeit_list_name _label">슬퍼요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list angry" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTC.angry|RTC.unangry" data-type="angry" href="#" role="button">
# <span class="u_likeit_list_name _label">화나요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# <li class="u_likeit_list want" role="menuitem">
# <a aria-selected="false" class="u_likeit_list_button _button" data-log="RTC.want|RTC.unwant" data-type="want" href="#" role="button">
# <span class="u_likeit_list_name _label">후속기사 원해요</span>
# <span class="u_likeit_list_count _count">0</span>
# </a>
# </li>
# </ul>
# </div>
# <!-- //좋아요 -->
# <!-- 이 기사 메인으로 -->
# <div class="tomain">
# <div class="u_likeit_list_module _reactionModule" data-cid="ne_055_0000445667" data-sid="NEWS_MAIN" id="toMainContainer">
# <a class="u_likeit_list_btn _button" data-ishiddenzerocount="true" data-log="RTC.recommend|RTC.unrecommend" data-type="like" href="#">
# <span class="u_ico"></span>
# <em class="u_txt _label">이 기사를 모바일 메인으로 추천</em>
# <em class="u_cnt _count"></em>
# </a>
# </div>
# </div>
# <!-- //이 기사 메인으로 -->
# <!-- [D] 공유 아이콘 -->
# <div class="sns_share">
# <a class="naver-splugin" data-band-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=band" data-blog-blog-id="naver" data-blog-source-type="3" data-blog-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=blog" data-cafe-source-type="3" data-cafe-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=cafe" data-calendar-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=calendar" data-facebook-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=facebook" data-likecontentsid="ne_055_0000445667" data-likeserviceid="NEWS" data-mail-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=mail" data-me-display="off" data-memo-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=memo" data-style="unity" data-title="[날씨] 한결 선선해진 바람…주말 30도 안팎" data-twitter-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667&amp;lfrom=twitter" data-url="http://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=001&amp;oid=055&amp;aid=0000445667" href="#" id="spiButton" title="보내기">
# <span class="naver-splugin-c sns_share_ico"></span>
# <span class="blind">보내기</span>
# </a>
# </div>
# <div class="tomain_info" id="tomain_info" style="display: none;">
# </div>
# <script id="TOMAIN_DISPLAYED_BY_USER_RECOMMEND_TPL" type="text/template">
# 		<p class="tomain_info_phrase">
# 			<span class="tomain_info_body">
# 				<span class="tomain_info_text">이 기사는 </span><strong class="tomain_info_point">사용자 추천</strong><span class="tomain_info_text">으로 모바일 메인 뉴스판에 노출된 이력이 있습니다.</span>
# 			</span>
# 		</p>
# 	</script>
# <script id="TOMAIN_DISPLAYED_BY_NEWS_EDIT_TPL" type="text/template">
# 		<p class="tomain_info_phrase">
# 			<span class="tomain_info_body">
# 				<span class="tomain_info_text">이 기사는 </span><strong class="tomain_info_point">모바일 메인 뉴스판</strong><span class="tomain_info_text">에 노출된 이력이 있습니다.</span>
# 			</span>
# 		</p>
# 	</script>
# <script id="TOMAIN_NOT_DISPLAYED_YET_TPL" type="text/template">
# 		<p class="tomain_info_layer">
# 			<strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# 			<span class="tomain_info_body">
# 				<strong class="tomain_info_point">이 기사를 메인으로 추천 </strong><span class="tomain_info_text">버튼을 눌러주세요. 집계 기간 동안 추천을 많이 받은 기사는 네이버 메인 뉴스판에 노출될 예정입니다. 비정상적인 추천기사는 제외될 수 있습니다.</span>
# 			</span>
# 			<a href="#" class="tomain_info_close">레이어 닫기</a>
# 		</p>
# 	</script>
# <script type="text/javascript">
#  		(function(){
# 			var currentDate = new Date(), yyyy = currentDate.getFullYear(), mm = currentDate.getMonth() + 1, dd = currentDate.getDate();
# 			var currentDateParam = "" + yyyy + (mm < 10 ? '0' + mm : mm) + (dd < 10 ? '0' + dd : dd);
# 			var id = "naver-splugin-sdk";
# 			var s = document.createElement("script"); s.id = id; s.type = "text/javascript", s.charset = "utf-8", s.async = false;
# 			s.src = ("http://spi.naver.net/js/release/ko_KR/splugin.js?" + currentDateParam);
# 			var d = document.getElementsByTagName('head')[0]; d.appendChild(s, d);
# 		})();
#  		(function(oData) {
# 		    var t = new Date(), yyyy = t.getFullYear(), mm = t.getMonth() + 1, dd = t.getDate();
# 		    var currentDate = "" + yyyy + (mm < 10 ? '0' + mm : mm) + (dd < 10 ? '0' + dd : dd);
# 		    var s = document.createElement("script");
# 		    s.type = "text/javascript";
# 		    s.charset = "utf-8";
# 		    s.src = "http://news.like.naver.com/js/reaction/dist/reaction.js?"+ currentDate; // (new Date()).toDateString().replace(/\s/g,"");
# 		    (document.head || document.getElementsByTagName("head")[0]).appendChild(s);
# 		})();
# 		window.onload = function() {
# 		    if(jindo.$Element("spiLayer").query("._reactionModule") !== null) {
# 				var toMainInfoLayerManager = {
#
# 					oCookieStorage : null,
# 					sCookieKey : null,
# 					sTemplateType : null,
# 					oTemplateType2TemplateMapping : null,
#
# 					welTomainInfoLayer : null,
#
# 					init : function () {
# 						this.setCache();
# 						this.setEvent();
#
# 						var dontShowAgainYn = this.oCookieStorage.get(this.sCookieKey);
# 						if (this.sTemplateType != 'N' || !dontShowAgainYn) {
# 							this.renderLayer();
# 						}
# 					},
#
# 					setCache : function () {
# 						this.oCookieStorage = jindo.$Cookie(true);
# 						this.sCookieKey = 'pcTomainDontShow';
# 						this.sTemplateType = 'E';
# 						this.oTemplateType2TemplateMapping = {
# 							'R' : 'TOMAIN_DISPLAYED_BY_USER_RECOMMEND_TPL',
# 							'E' : 'TOMAIN_DISPLAYED_BY_NEWS_EDIT_TPL',
# 							'N' : 'TOMAIN_NOT_DISPLAYED_YET_TPL'
# 						};
# 						this.welTomainInfoLayer = jindo.$Element('tomain_info');
# 					},
#
# 					setEvent : function () {
# 						this.welTomainInfoLayer.delegate('click', '.tomain_info_close', jindo.$Fn(this.onCloseClick, this).bind());
# 					},
#
# 					renderLayer : function () {
# 						var sTemplate = this.oTemplateType2TemplateMapping[this.sTemplateType];
# 						this.welTomainInfoLayer.html(jindo.$Template(sTemplate).process({}));
# 						this.welTomainInfoLayer.show();
# 					},
#
# 					onCloseClick : function (e) {
# 						e.stopDefault();
# 						this.welTomainInfoLayer.hide();
# 						this.oCookieStorage.set(this.sCookieKey, 'Y', 365);
# 					}
#
# 				};
#
# 				var toMainManager = {
#
# 					welContainer : null,
# 					welCount : null,
# 					welButton : null,
#
# 					init : function () {
# 						this.welContainer = jindo.$Element('toMainContainer');
# 						this.welCount = jindo.$Element(this.welContainer.query('._count'));
# 						this.welButton = jindo.$Element(this.welContainer.query('a'));
# 					},
#
# 					// 추천 수가 0인 경우, 디자인이 달라서 is_first 클래스 추가
# 					addIsFirstClassIfZeroCount : function () {
# 						if (this.welCount.text() == '0') {
# 							this.welButton.removeClass('off').addClass('is_first');
# 						}
# 					},
#
# 					removeIsFirstClass : function () {
# 						this.welButton.removeClass('is_first');
# 					},
#
# 					onRecommend : function () {
# 						this.removeIsFirstClass();
# 					},
#
# 					onCancel : function () {
# 						this.addIsFirstClassIfZeroCount();
# 					},
#
# 					onRecommendReady : function (element) {
# 						this.addIsFirstClassIfZeroCount();
# 					}
# 				};
#
# 				toMainInfoLayerManager.init();
# 				toMainManager.init();
#
# 				reaction.init({
# 					type: "multi",
# 					domain : "http://news.like.naver.com",
# 					dependentLibrary : "jquery",
# 					cssId: "news",
# 					isMobile: false,
# 					isHiddenLabel : false,
# 					isHiddenCount : false,
# 					isHiddenZeroCount : false,
# 					isUsedLabelAsZeroCount : false,
# 					isDebugMode : false,
# 					isHiddenLayerAfterSelection : true,
# 					callback : {
# 						clicked : function(param) {
# 							// displayId 가 'NEWS_MAIN' 이면 '메인으로추천', 'NEWS'면 '좋아요'
# 							if (param && param.content && param.content.displayId && param.content.displayId == 'NEWS_MAIN') {
# 								if(param.content.isReacted) {
# 									toMainManager.onRecommend();
# 									return;
# 								}
# 								toMainManager.onCancel();
# 							}
# 						},
# 						updated : function(param) {
# 							if (param) {
# 								jindo.$A(param.contents).filter(function (content) {
# 									if (content.serviceId == 'NEWS_MAIN') {
# 										return true;
# 									}
# 									return false;
# 								}).forEach(function (content) {
# 									toMainManager.onRecommendReady();
# 								});
# 							}
# 						}
# 					}
# 				});
# 			}
#
# 		    // for social plugin
# 			window.__splugin = SocialPlugIn_Core({
# 				// nEvent Key
# 				"evKey"       : "news",
# 				// 서비스명
# 				"serviceName" : "뉴스",
# 				"sourceName" : "SBS 뉴스",
# 				// 버튼 클릭후 호출되는 콜백함수
# 				"onClick"     : function(button) {},
# 				// 공유하기 레이어 노출 후 호출되는 콜백함수
# 				"onShow"      : function() {},
# 				// 공유하기 레이어 닫기 후 호출되는 콜백함수
# 				"onHide"      : function() {}
# 			});
# 		}
#
# 		function onSubscribe(elTarget) {
# 			return htParameter;
# 		}
# 	</script>
# </div>
# <!-- // 소셜플러그인 -->
# <script type="text/javascript">
# /* (function() {
# 	init_socialplugin();
# })(); */
# </script>
# <script type="text/javascript">
#     jindo.$Fn(function() {
#         jindo.$Fn(function(){
#             var oid = '055';
#             var aid = '0000445667';
#             new jindo.$Ajax('/main/ajax/series/list.nhn?oid=' + oid + '&aid=' + aid, {
#                 type : 'xhr',
#                 method : 'get',
#                 timeout : 10,
#                 async : true,
#                 onload : function(res) {
#                     var oJson = res.json();
#                     if (oJson.message != null && oJson.message.result != null) {
#                         var result = oJson.message.result;
#                         var contents = '<div class="serialization_news"><h3 class="serialization_news_title"><span class="serialization_news_ico">연재</span>'
#                             + '<a href="'+result.linkUrl+'" class="serialization_news_more" id="seriesTitle" onclick="nclk(this, \'ser.more\',\'\', \'\')" >'
#                             + result.title + '</a><span class="blind">더보기</span></h3>'
#                             + '<ul class="serialization_news_list">';
#
#                         result.seriesItemList.forEach(function(value) {
#                             if (value) {
#                                 if (aid == value.articleId) {
#                                     contents += '<li><div class="serialization_news_item"><span class="serialization_news_time">'+ value.articleDate +'</span><a href="'+value.url+'" class="serialization_news_link is_selected" onclick="nclk(this,\'ser.art\',\'\',\'\')">' + value.title + '</a></div></li>';
#                                 } else {
#                                     contents += '<li><div class="serialization_news_item"><span class="serialization_news_time">'+ value.articleDate +'</span><a href="'+value.url+'" class="serialization_news_link" onclick="nclk(this,\'ser.art\',\'\',\'\')">' + value.title + '</a></div></li>';
#                                 }
#                             }
#                         });
#
#                         contents += '</ul></div>';
#
#                         $Element('spiLayer').afterHTML(contents);
#
#                         var elLinkNews = $$('.link_news');
#                         if (elLinkNews.length > 0) {
#                             $Element('link_news_more').first().text(result.title);
#                             $Element('link_news_more').visible(true, 'block');
#                             $Element('link_news_more').attr('href', result.linkUrl);
#                         }
#                     }
#                 }
#             }).request();
#         }).delay(0.8);
#     }).attach(window, "load");
# </script>
# <!-- 언론사 관련기사 -->
# <div class="link_news">
# <h3>SBS 뉴스 관련뉴스<span>언론사 페이지로 이동합니다.</span></h3>
# <ul>
# <li><a class="nclicks(are.link,'055', 'nilGParam', '055_dcfa778ba74b550b')" href="http://news.sbs.co.kr/news/endPage.do?news_id=N1003752126&amp;oaid=N1003752467&amp;plink=REL1&amp;cooper=NAVER" target="_blank">서울 갑자기 19.5도…거짓말같이 폭염 사라진 이유</a></li>
# <li><a class="nclicks(are.link,'055', 'nilGParam', '055_bd472885372f5085')" href="http://news.sbs.co.kr/news/endPage.do?news_id=N1003751977&amp;oaid=N1003752467&amp;plink=REL2&amp;cooper=NAVER" target="_blank">이인원 유서 "신동빈 회장 훌륭한 사람…먼저 가 미안"</a></li>
# <li><a class="nclicks(are.link,'055', 'nilGParam', '055_7894bee66132e566')" href="http://news.sbs.co.kr/news/endPage.do?news_id=N1003751337&amp;oaid=N1003752467&amp;plink=REL3&amp;cooper=NAVER" target="_blank">남의 집 딸 코 물어뜯고는…'슬쩍' 이사 가버린 이웃</a></li>
# <li><a class="nclicks(are.link,'055', 'nilGParam', '055_7e36218aa0f7dbca')" href="http://news.sbs.co.kr/news/endPage.do?news_id=N1003752058&amp;oaid=N1003752467&amp;plink=REL4&amp;cooper=NAVER" target="_blank">'트랜스젠더 케이크' 판 동네빵집…악플 세례에 곤욕</a></li>
# <li><a class="nclicks(are.link,'055', 'nilGParam', '055_7ada15e543722f25')" href="http://news.sbs.co.kr/news/endPage.do?news_id=N1003751622&amp;oaid=N1003752467&amp;plink=REL5&amp;cooper=NAVER" target="_blank">여성만 참가하는 '히잡 카레이싱'…독특한 우승방법</a></li>
# </ul>
# <a class="link_news_more" href="#" id="link_news_more" onclick="nclk(this, 'ser.sum', '', '');" style="display:none"><em></em> 기사 모아보기</a>
# </div>
# <!-- // 언론사 관련기사 -->
# </div>
# <!-- 언론중재법 -->
# <!-- // 언론중재법 --><!-- 기능 버튼 영역 -->
# <div class="article_footer">
# <ul>
# <li>
# <a href="http://news.sbs.co.kr/" target="_blank">
# 			SBS 뉴스 기사제공
# 			</a>
# </li>
# <li>|
# 					<a class="go" href="/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=055">SBS 뉴스 기사목록</a></li>
# </ul>
# </div>
# <ul class="content_menu content_menu_bottom">
# <li class="first"><a alt="인쇄" class="print" href="/main/tool/print.nhn?oid=055&amp;aid=0000445667" target="_blank" title="인쇄">인쇄</a></li>
# <li class="scrap"><a alt="스크랩" class="scrap" href="/main/scrap/folderList.nhn?scrapItem.officeId=055&amp;scrapItem.articleId=0000445667" target="_blank" title="스크랩">스크랩</a></li>
# </ul>
# <!-- // 기능 버튼 영역 -->
# <!-- (신)관련기사 -->
# <!-- //(신)관련기사 -->
# <!-- 스포츠 관련기사 -->
# <!-- //스포츠 관련기사 -->
# <!-- 본문 하단 광고 -->
# <div class="end_ad"><iframe align="center" border="0" data-veta-preview="p_news_end" frameborder="0" height="0" id="f540100" marginheight="0" marginwidth="0" name="f540100" scrolling="no" src="http://veta.naver.com/fxshow?su=SU10083&amp;sid1=103&amp;sid2=245&amp;oid=055" title="배너광고" width="573"></iframe></div>
# <!-- // 본문 하단 광고 -->
# <div id="cbox_module"></div>
# <script type="text/javascript">
# var isLogForComment = false;
# if (jindo.$Cookie().get('NID_SES') != null && jindo.$Cookie().get('NID_SES') != ''){
#     isLogForComment = true;
# }
#
# jindo.$Fn(function() {
#     (function(htOption) {
#         window.__htCboxOption = htOption;
#         var s = document.createElement('script');
#         s.type = 'text/javascript';
#         s.charset = 'utf-8';
#         s.src = htOption.sDomain + '/js/cbox.core.js?v=' + Math.floor(new Date().getTime() / 1200000);
#         (document.head || document.getElementsByTagName("head")[0]).appendChild(s);
#     })({
#         sDomain : 'http://static.cbox.naver.net',
#         sApiDomain : 'https://apis.naver.com/commentBox/cbox5',
#         bLogin : isLogForComment,
#         sTicket : 'news',
#         sTemplateId : 'view_life',
#         sObjectId : 'news055,0000445667',
#         sLikeItId : 'ne_055_0000445667',		//좋아요 아이디
#         bUseAgo : false,
#         sCategoryId : '',
#         sCategoryImage : '',
#         sGroupId : '',
#         sHelp : 'down',
#         sLanguage : 'ko',
#         sCountry : '',
#         aFormation : ['count', 'graph', 'write', 'notice', 'list', 'view'],
#         sPageType : 'more',
#         nPageSize : 10,
#         nReplyPageSize : 20,
#         sCssId : 'news',
#         bByCountry : false,
#         bIncludeAllComments : true,
#         bManager : false,
#         sCommentNo : location.search.split("commentNo=")[1] == null ? '' : location.search.split("commentNo=")[1].split("&")[0],
#         sCategoryImage : '',
#         sSort :'',
#         bSortCookie : true,
#         sCountType :'comment',
#         aExcludeCountry : [],
#         sAreaCodePrefix : '',
#         sAuthType: 'both',
#         sCharset: 'euc-kr',
#         bShowReply : location.search.split("showReply=")[1] == null ? '' : location.search.split("showReply=")[1].split("&")[0],
#         sDateFormat : 'Y-m-d H:i:s',
#
#         vViewAllHandler : CommentUtils.processViewAllCommentsWithOption,
#
#         htEventHandler : {
#             loadList : function(oEvent) {
# ...
# this.toggle(selectedIndex);
# }
# },
# toggle : function(selectedIndex) {
# var self = this;
# this.tabList.forEach(function(value, index, array) {
# var wel = jindo.$Element(value);
# if (selectedIndex === index) {
# wel.html('<strong>' + wel.html() + '</strong>');
# wel.addClass("is_click");
# } else if (self.currentIndex === index) {
# wel.html(wel.first().html());
# wel.removeClass("is_click");
# }
# });
# this.contentsList.forEach(function(value, index, array) {
# var wel = jindo.$Element(value);
# if (selectedIndex === index) {
# wel.show();
# } else {
# wel.hide();
# }
# });
# this.currentIndex = selectedIndex;
# }
# }
# rightDailyList.init();
# </script>
# <div class="section" style="margin-bottom:20px;">
# <h4><a class="nclicks(rig.banner)" href="http://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;cid=1019690">상식in뉴스</a></h4>
# <div class="banner">
# <a class="nclicks(rig.banner)" href="http://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;cid=1019690"><img alt="상식in뉴스" src="http://imgnews.naver.net/image/upload/item/2015/03/18/095339765_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_244X90.png" width="244"/></a>
# </div>
# <a class="more_link nclicks(rig.banner)" href="http://news.naver.com/main/hotissue/sectionList.nhn?mid=hot&amp;sid1=110&amp;cid=1019690"><img alt="상식in뉴스 더보기" height="13" src="http://static.news.naver.net/image/news/2009/txt_more_link2.gif" width="33"/></a>
# </div>
# <div class="section hottopic" id="newstopic_container">
# <h4>뉴스토픽</h4>
# <div class="category" id="newstopic_tab" role="tablist">
# <a aria-selected="true" class="is_click" data-tab="news" href="#" onclick="return false;" role="tab">뉴스</a>
# <a aria-selected="false" data-tab="entertain" href="#" onclick="return false;" role="tab">연예/스포츠</a>
# </div>
# <ol class="type15" id="newstopic_news">
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%84%9C%ED%95%B4+%EA%B5%B0+%ED%86%B5%EC%8B%A0%EC%84%A0+%EB%B3%B5%EC%9B%90&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="서해 군 통신선 복원"><span class="rank"><em>1</em></span> <strong class="title">서해 군 통신선 복원</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%84%EC%9B%90+%EA%B5%AC%EC%86%8D%EC%98%81%EC%9E%A5&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="전원 구속영장"><span class="rank"><em>2</em></span> <strong class="title">전원 구속영장</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9E%84%EB%8B%A8%ED%98%91+%EC%9E%A0%EC%A0%95%ED%95%A9%EC%9D%98%EC%95%88+%EB%B6%80%EA%B2%B0&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="임단협 잠정합의안 부결"><span class="rank"><em>3</em></span> <strong class="title">임단협 잠정합의안 부결</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%82%A8%EB%B6%81+%EA%B3%A0%EC%9C%84%EA%B8%89%ED%9A%8C%EB%8B%B4&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="남북 고위급회담"><span class="rank"><em>4</em></span> <strong class="title">남북 고위급회담</strong> <span class="rank2"></span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9D%B8%EC%B2%9C+%EC%97%AC%EA%B3%A0%EC%83%9D+%ED%8F%AD%ED%96%89&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="인천 여고생 폭행"><span class="rank"><em>5</em></span> <strong class="title">인천 여고생 폭행</strong> <span class="rank2"></span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%E6%96%87%EB%8C%80%ED%86%B5%EB%A0%B9+%ED%95%9C+UAE&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="文대통령 한 UAE"><span class="rank"><em>6</em></span> <strong class="title">文대통령 한 UAE</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%ED%87%B4%EA%B7%BC%EA%B8%B8+%EB%84%98%EC%96%B4%EC%A0%B8+%EA%B3%A8%EC%A0%88&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="퇴근길 넘어져 골절"><span class="rank"><em>7</em></span> <strong class="title">퇴근길 넘어져 골절</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B4%91%EC%A3%BC+%EA%B4%91%EC%82%B0%EA%B5%AC&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="광주 광산구"><span class="rank"><em>8</em></span> <strong class="title">광주 광산구</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%94%EB%A5%B8%EC%A0%95%EB%8B%B9+%ED%83%88%EB%8B%B9&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="바른정당 탈당"><span class="rank"><em>9</em></span> <strong class="title">바른정당 탈당</strong> <span class="rank2"></span></a></li>
# <li><a class="nclicks(rig.newstopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B6%88+%EB%B0%9D%ED%9E%8C+%ED%8F%89%ED%99%94%EC%9D%98+%EC%A7%91&amp;ie=utf8&amp;sm=nws_htk.nws" target="_blank" title="불 밝힌 평화의 집"><span class="rank"><em>10</em></span> <strong class="title">불 밝힌 평화의 집</strong> <span class="rank2">NEW</span></a></li>
# </ol>
# <ol class="type15" id="newstopic_entertain" style="display: none;">
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%8F%8C%EC%95%84%EC%98%A8+%EB%B0%95%EB%B3%91%ED%98%B8&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="돌아온 박병호"><span class="rank"><em>1</em></span> <strong class="title">돌아온 박병호</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EC%B0%AC%EC%9A%B1+%EC%95%84%EA%B0%80%EC%94%A8&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="박찬욱 아가씨"><span class="rank"><em>2</em></span> <strong class="title">박찬욱 아가씨</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=2TV+%EC%83%9D%EC%83%9D%EC%A0%95%EB%B3%B4&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="2TV 생생정보"><span class="rank"><em>3</em></span> <strong class="title">2TV 생생정보</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EA%B3%A0%EB%82%98%EC%9D%80%EC%9C%BC%EB%A1%9C+%EA%B0%9C%EB%AA%85&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="고나은으로 개명"><span class="rank"><em>4</em></span> <strong class="title">고나은으로 개명</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%98%A4%EB%A7%88%EC%9D%B4%EA%B1%B8+%EC%A7%84%EC%9D%B4&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="오마이걸 진이"><span class="rank"><em>5</em></span> <strong class="title">오마이걸 진이</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%B0%A8%EC%83%81%ED%98%84+%EA%B0%90%EB%8F%85&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="차상현 감독"><span class="rank"><em>6</em></span> <strong class="title">차상현 감독</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%82%B4+%EB%82%A8%EC%9E%90%EC%9D%98+%EB%B9%84%EB%B0%80&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="내 남자의 비밀"><span class="rank"><em>7</em></span> <strong class="title">내 남자의 비밀</strong> <span class="rank2"></span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EB%91%A5%EC%A7%80%ED%83%88%EC%B6%9C2+%EC%9C%A0%EC%84%A0%ED%98%B8&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="둥지탈출2 유선호"><span class="rank"><em>8</em></span> <strong class="title">둥지탈출2 유선호</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%84%EC%83%9D%EC%97%90+%EC%9B%AC%EC%88%98%EB%93%A4+%ED%95%9C%EC%A7%84%ED%9D%AC&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="전생에 웬수들 한진희"><span class="rank"><em>9</em></span> <strong class="title">전생에 웬수들 한진희</strong> <span class="rank2">NEW</span></a></li>
# <li><a class="nclicks(rig.entopic)" href="http://search.naver.com/search.naver?where=nexearch&amp;query=%EC%9D%B4%EC%98%81%ED%95%98+%EC%82%AC%EB%9E%91%EC%A4%91+%EC%9D%B4%EB%B3%84%EC%9D%B4+%EB%B0%9C%ED%91%9C&amp;ie=utf8&amp;sm=nws_htk.ent" target="_blank" title="이영하 사랑중 이별이 발표"><span class="rank"><em>10</em></span> <strong class="title">이영하 사랑중 이별이 발표</strong> <span class="rank2"></span></a></li>
# </ol>
# <p>
# <span class="newstopic_error_text">추출이 일시적으로 늦어져 최신 정보를 제공할 수 없습니다.</span>
# <span class="newstopic_time">2018.01.09. 17:30 ~ 20:30 기준<a class="newstopic_help nclicks(rig.hotopic)" href="#" onclick="news.external.OPS.helpHotTopicKeyword(); return false;" target="_blank" title="새창"><span class="blind">도움말</span></a></span>
# </p>
# </div>
# <script type="text/javascript">
# var newsTopicInfo = {
# welContainer : null,
# welTabContainer : null,
# welTabList : null,
# welTopicList : null,
# initialize : function() {
# this.setCache();
# this.setEvent();
# },
# setCache : function() {
# this.welContainer = jindo.$Element('newstopic_container');
# this.welTabContainer = jindo.$Element('newstopic_tab');
# this.welTabList = jindo.$ElementList(this.welTabContainer.queryAll('a'));
# this.welTopicList = jindo.$ElementList(this.welContainer.queryAll('ol'));
# },
# setEvent : function() {
# this.welTabContainer.delegate('mouseover', 'a', jindo.$Fn(this.onTabMouseOver, this).bind());
# this.welTabContainer.delegate('click', 'a', jindo.$Fn(this.onTabClick, this).bind());
# },
# onTabClick : function(e){
# e.stopDefault();
# },
# onTabMouseOver : function(e) {
# this.welTabList.removeClass('is_click').attr('aria-selected', false);
# var tabName = jindo.$Element(e.element).addClass('is_click').attr('aria-selected', true).attr('data-tab');
# this.welTopicList.hide();
# jindo.$Element('newstopic_' + tabName).show();
# }
# };
# newsTopicInfo.initialize();
# </script>
# </div>
# </td>
# </tr>
# </table>
# <div class="lyr_dimmed lyr_sc_alert" id="lyr_dimmed" style="margin-top:-268px">
# <h5 class="blind">욕설 댓글 리마인드 팝업</h5>
# <div class="lyr_dimmed_topdeco"></div>
# <div class="lyr_dimmed_content">
# <img/>
# <div class="lyr_sc_btmtext">
# <p class="blind">상처 없는 댓글 세상 만들기에 많은 참여 부탁드립니다.</p>
# </div>
# <a class="btn_dimmed_confirm" href="#" onclick="commentLayer.hideCommentLayer();return false;"><span class="blind">확인</span></a>
# </div>
# <div class="lyr_dimmed_btmdeco"></div>
# </div>
# <script type="text/javascript">
# var commentLayer = {
# 	init : function () {
# 		this._oFoggy = new jindo.Foggy();
# 		this._welLayer = jindo.$Element("lyr_dimmed");
#
# 		var oImg = this._welLayer.query("img");
# 		var nIndex = Math.floor(Math.random() * 5);
# 		var aImageInfo = [{width:419,height:248,alt:"도산 안창호. 남의 결점을 지적하더라도 결코 듣기 싫은 말로 하지말고 사랑으로써 할 것이외다"},
# 		                  {width:470,height:208,alt:"모로코 속담. 말이 입힌 상처는 칼이 입힌 상처보다 깊다"},
# 		                  {width:453,height:208,alt:"댓글에 상처받는 이는 바로 우리의 이웃입니다"},
# 		                  {width:481,height:208,alt:"댓글 안에 당신의 성숙함도 함께 담아주세요"},
# 		                  {width:406,height:208,alt:"당신의 댓글, 소리내어 읽어보셨나요?"}];
# 		var welImg = jindo.$Element(oImg);
# 		welImg.attr('src', 'http://static.news.naver.net/image/news/2015/02/lyr_sc_text' + (nIndex+1) + '.gif');
# 		welImg.attr('width', aImageInfo[nIndex].width);
# 		welImg.attr('height', aImageInfo[nIndex].height);
# 		welImg.attr('alt', aImageInfo[nIndex].alt);
# 		return this;
# 	},
# 	showCommentLayer : function (sNclkHead) {
# 		this._sNclkHead = sNclkHead;
# 		this._welLayer.show();
# 		this._oFoggy.show();
# 	},
# 	hideCommentLayer : function () {
# 		this._welLayer.hide();
# 		this._oFoggy.hide();
# 		var tempNsc = nsc;
# 		nsc = "news.reply";
#         nclk(this, this._sNclkHead + '.camp','','');
# 		nsc = tempNsc;
# 	}
# }.init();
# </script>
# <hr/>
# <div class="index">
# <div class="page_navi">
# <a class="prev" href="javascript:history.back();">이전페이지로 돌아가기</a>
# <span class="bar">|</span><a class="top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;">맨위로</a>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="loading" style="display:none;">로딩 중</span></a>
# <div id="index.press.area" style="display:none;"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02" id="index.category.area" style="display:none;"></div>
# <span class="stit3">
# <span class="bar">|</span>
# <a class="spr nclicks(fot.scrap)" href="/main/scrap/index.nhn">마이스크랩</a>
# </span>
# </div>
# <dl class="type01 fs11">
# <dt></dt>
# <dd>
# </dd>
# </dl>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a href="/main/ombudsman/index.nhn">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.nhn?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 정연아</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_cp nclicks(fot.presscr)">저작권자(c) <a href="http://news.sbs.co.kr/" target="blank">SBS &amp; SBSi </a>.All right reserved. 무단 전재-재배포 금지</address>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="http://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="http://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
# new news.lnb.NewsSearchController('lnb.searchForm');
#
#
#
# var lnb_weatherRolling = new news.lnb.LineRolling('lnb.weather',{size:26,moveSize:3,moveInterval:30});
# var lnb_mainnewsRolling = new news.lnb.LineRolling('lnb.mainnews',{size:17,moveSize:2,moveInterval:30,isRandomStart:true});
# var lnb_Rolling = new news.lnb.SynchronizedRolling({interval:3000});
# lnb_Rolling.push(lnb_weatherRolling);
# lnb_Rolling.push(lnb_mainnewsRolling);
# lnb_Rolling.start();
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.nhn'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.nhn'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		news.read.Toolbar.init({
# 			oid : '055',
# 			aid : '0000445667',
# 			isLogin : false
# 		});
#
#
#
#
#
#
#
# 	lcs_do_gdid("8800011C_000000000000000000445667");
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </div>
# </body>
# </html>

# %%
text = ''
txtlist = []
count = 1;
for item in soup.find_all('div', id='articleBodyContents'):
    print (item, '@@ item type is ', type(item))
    itfnd = item.find_all(text=True)
    txtlist += list(itfnd) # list() type casting 없어도 그냥 리스트로 합쳐지더라.
    print (count, itfnd, type(itfnd))
    count += 1
    text = text + str(item.find_all(text=True))
#    return text
# Out:
# <div id="articleBodyContents">
# <!-- 본문 내용 -->
# <!-- TV플레이어 -->
# <div class="vod_area">
# <iframe _src="/main/readVod.nhn?oid=055&amp;aid=0000445667&amp;foreignPlayVod=true" allowfullscreen="" frameborder="0" height="342" marginheight="0" marginwidth="0" title="영상 플레이어" width="544"></iframe>
# </div>
# <!-- // TV플레이어 -->
# <script type="text/javascript">
# // flash 오류를 우회하기 위한 함수 추가
# function _flash_removeCallback() {}
# </script>
#
# 	네, 바람이 한결 선선해졌습니다.<br/><br/>그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.<br/><br/>폭염이 물러가고 열대야도 대부분 해소됐습니다.<br/><br/>이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.<br/><br/>또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.<br/><br/>지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.<br/><br/>이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.<br/><br/>남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.<br/><br/>오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.<br/><br/>주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.<br/><br/>또 그리고 당분간 늦더위는 계속될 전망입니다.<br/><br/>(이나영 기상캐스터) <br/><br/><br/><br/><p>※ ⓒ SBS &amp; SBS콘텐츠허브 : 무단복제 및 재배포 금지<br/><a href="http://news.sbs.co.kr/news/inform.do?plink=FOOT&amp;cooper=NAVER">☞ SBS뉴스에 영상 제보하고 상품권 받기!</a></p>
# <!-- // 본문 내용 -->
# </div> @@ item type is  <class 'bs4.element.Tag'>
# 1 ['\n', ' 본문 내용 ', '\n', ' TV플레이어 ', '\n', '\n', '\n', '\n', ' // TV플레이어 ', '\n', '\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n', '\n\t\n\t네, 바람이 한결 선선해졌습니다.', '그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.', '폭염이 물러가고 열대야도 대부분 해소됐습니다.', '이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.', '또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.', '지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.', '이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.', '남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.', '오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.', '주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.', '또 그리고 당분간 늦더위는 계속될 전망입니다.', '(이나영 기상캐스터)\xa0', '※ ⓒ SBS & SBS콘텐츠허브 : 무단복제 및 재배포 금지', '☞ SBS뉴스에 영상 제보하고 상품권 받기!', '\n', ' // 본문 내용 ', '\n'] <class 'bs4.element.ResultSet'>

# %%
itfnd
# Out:
# ['\n',
#  ' 본문 내용 ',
#  '\n',
#  ' TV플레이어 ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' // TV플레이어 ',
#  '\n',
#  '\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n',
#  '\n\t\n\t네, 바람이 한결 선선해졌습니다.',
#  '그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.',
#  '폭염이 물러가고 열대야도 대부분 해소됐습니다.',
#  '이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.',
#  '또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.',
#  '지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.',
#  '이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.',
#  '남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.',
#  '오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.',
#  '주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.',
#  '또 그리고 당분간 늦더위는 계속될 전망입니다.',
#  '(이나영 기상캐스터)\xa0',
#  '※ ⓒ SBS & SBS콘텐츠허브 : 무단복제 및 재배포 금지',
#  '☞ SBS뉴스에 영상 제보하고 상품권 받기!',
#  '\n',
#  ' // 본문 내용 ',
#  '\n']

# %%
txtlist
# Out:
# ['\n',
#  ' 본문 내용 ',
#  '\n',
#  ' TV플레이어 ',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  ' // TV플레이어 ',
#  '\n',
#  '\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}\n',
#  '\n\t\n\t네, 바람이 한결 선선해졌습니다.',
#  '그동안 힘들었던 폭염이 물러갔는데요, 시원한 단비가 내린 데다가 찬 공기가 내려왔기 때문입니다.',
#  '폭염이 물러가고 열대야도 대부분 해소됐습니다.',
#  '이제 큰 더위 걱정은 안 하셔도 되겠는데요, 오늘(26일) 서울의 낮 기온 28도로 정말 모처럼 30도 아래로 내려왔습니다.',
#  '또 내일과 모레 주말 동안 30도 안팎에 머물겠지만, 그동안처럼 혹독한 폭염은 없겠습니다.',
#  '지금 비는 대부분 그쳤는데요, 주로 충청과 경북 지방을 중심으로 비가 내리고 있습니다.',
#  '이 비도 낮에는 대부분 그치겠고요, 동해안은 동풍의 영향으로 오후까지 비가 조금 내리겠습니다.',
#  '남부 지방은 대기 불안정으로 밤까지 요란한 소나기가 지나겠습니다.',
#  '오늘 낮 기온은 서울, 대전, 전주 28도, 대구 25도로 어제보다 기온이 많게는 10도나 뚝 떨어지겠습니다.',
#  '주말인 내일 중부 지방은 구름만 많겠지만, 영동과 남부 지방은 비 소식이 있는데요, 내일 밤 비가 시작돼 모레까지 이어지겠습니다.',
#  '또 그리고 당분간 늦더위는 계속될 전망입니다.',
#  '(이나영 기상캐스터)\xa0',
#  '※ ⓒ SBS & SBS콘텐츠허브 : 무단복제 및 재배포 금지',
#  '☞ SBS뉴스에 영상 제보하고 상품권 받기!',
#  '\n',
#  ' // 본문 내용 ',
#  '\n']

# %%
txtlist[0] == '\n'
# Out:
# True

# %%
type (txtlist[0])
# Out:
# bs4.element.NavigableString

# %%
len(txtlist[0])
# Out:
# 1

# %%
txtlist[0][0] is '\n'
# Out:
# True

# %%
txtlist[1][1] == '본'
# Out:
# True

# %% [markdown]
# ## 파이선 > 3.5 에서 사용하는 한글 인코딩 시스템을 이해해야한다.
#
# ### Python3는 모든 문자열을 유니코드(unicode)로 처리하기 때문에 str과 unicode가 완전히 동일하다.
# https://financedata.github.io/posts/faq_crawling_data_encoding.html

# %%
s = "한글 eng"
print (type(s), len(s))
# Out:
# <class 'str'> 6

# %%
import chardet

# %%
euc_data = '한글'.encode('euc-kr')
print (chardet.detect(euc_data))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
utf8_data = '한글'.encode('utf-8') # default is unicode-8
print (chardet.detect(utf8_data))
# Out:
# {'encoding': 'utf-8', 'confidence': 0.7525, 'language': ''}

# %% [markdown]
# ### 네이버 실시간 검색어 순위 JSON 데이터를 가져오기
# https://financedata.github.io/posts/naver_realtime_search_json.html

# %%
import json, requests
from pandas.io.json import json_normalize

r = requests.get('http://rank.search.naver.com/rank.js')
jn = json_normalize(json.loads(r.text), ['data', 'data'])
ts = json.loads (r.text)['ts']
print ('time stamp = ', ts)
print ('실시간 순위', jn)
# Out:
# time stamp =  2018-01-09T22:25:00+0900
# 실시간 순위    change  cvalue  delta        keyword  rank ratio  score    tvalue
# 0       +    1736      0            투깝스     1     .     84  28.44082
# 1       +     422      0             염력     2     .    138  27.97407
# 2       +     715      0         뭉쳐야 뜬다     3     .    132  33.58800
# 3       +    1021      0         의문의 일승     4     .     99  21.25690
# 4       +     362      0           오마이걸     5     .    120  19.86568
# 5       +    3090      0            강식당     6     .     42  19.51452
# 6       +    2055      1           저글러스     7     +     54  17.92747
# 7       +      78      1            모네로     8     -    198   7.91751
# 8       +    1094      1  막돼먹은 영애씨 시즌16     9     +    117  16.40265
# 9       +      92      1            애간장    10     -    195   5.09282
# 10      +      90      0            정유미    11     .     93   4.55405
# 11      +     159      0         kbs온에어    12     .     69   4.18898
# 12      +      61      0        렉스턴 스포츠    13     .     66   4.02810
# 13      +      75      0         mbc온에어    14     .    102   3.39028
# 14      +      64      0         인터파크티켓    15     .     51   2.88274
# 15      +      52      1            itq    16     +     75   2.80883
# 16      +      76      1        sbs 온에어    17     -     84   2.79476
# 17      +     131      0         국세청홈택스    18     .     36   2.62376
# 18      +      52      0           강다니엘    19     .     54   2.14574
# 19      +      59      0            sbs    20   new     75   2.00990

# %%
r.text
# Out:
# '{"ts":"2018-01-09T22:25:00+0900","st":"2018-01-09T22:01:00+0900","et":"2018-01-09T22:11:00+0900","data":[{"category":"general","data":[{"rank":1,"keyword":"투깝스","change":"+","score":84,"tvalue":28.44082,"cvalue":1736,"ratio":".","delta":0},{"rank":2,"keyword":"염력","change":"+","score":138,"tvalue":27.97407,"cvalue":422,"ratio":".","delta":0},{"rank":3,"keyword":"뭉쳐야 뜬다","change":"+","score":132,"tvalue":33.588,"cvalue":715,"ratio":".","delta":0},{"rank":4,"keyword":"의문의 일승","change":"+","score":99,"tvalue":21.2569,"cvalue":1021,"ratio":".","delta":0},{"rank":5,"keyword":"오마이걸","change":"+","score":120,"tvalue":19.86568,"cvalue":362,"ratio":".","delta":0},{"rank":6,"keyword":"강식당","change":"+","score":42,"tvalue":19.51452,"cvalue":3090,"ratio":".","delta":0},{"rank":7,"keyword":"저글러스","change":"+","score":54,"tvalue":17.92747,"cvalue":2055,"ratio":"+","delta":1},{"rank":8,"keyword":"모네로","change":"+","score":198,"tvalue":7.91751,"cvalue":78,"ratio":"-","delta":1},{"rank":9,"keyword":"막돼먹은 영애씨 시즌16","change":"+","score":117,"tvalue":16.40265,"cvalue":1094,"ratio":"+","delta":1},{"rank":10,"keyword":"애간장","change":"+","score":195,"tvalue":5.09282,"cvalue":92,"ratio":"-","delta":1},{"rank":11,"keyword":"정유미","change":"+","score":93,"tvalue":4.55405,"cvalue":90,"ratio":".","delta":0},{"rank":12,"keyword":"kbs온에어","change":"+","score":69,"tvalue":4.18898,"cvalue":159,"ratio":".","delta":0},{"rank":13,"keyword":"렉스턴 스포츠","change":"+","score":66,"tvalue":4.0281,"cvalue":61,"ratio":".","delta":0},{"rank":14,"keyword":"mbc온에어","change":"+","score":102,"tvalue":3.39028,"cvalue":75,"ratio":".","delta":0},{"rank":15,"keyword":"인터파크티켓","change":"+","score":51,"tvalue":2.88274,"cvalue":64,"ratio":".","delta":0},{"rank":16,"keyword":"itq","change":"+","score":75,"tvalue":2.80883,"cvalue":52,"ratio":"+","delta":1},{"rank":17,"keyword":"sbs 온에어","change":"+","score":84,"tvalue":2.79476,"cvalue":76,"ratio":"-","delta":1},{"rank":18,"keyword":"국세청홈택스","change":"+","score":36,"tvalue":2.62376,"cvalue":131,"ratio":".","delta":0},{"rank":19,"keyword":"강다니엘","change":"+","score":54,"tvalue":2.14574,"cvalue":52,"ratio":".","delta":0},{"rank":20,"keyword":"sbs","change":"+","score":75,"tvalue":2.0099,"cvalue":59,"ratio":"new","delta":0}]}]}'

# %%
r.status_code
# Out:
# 200

# %%
r.headers
# Out:
# {'Server': 'nginx', 'Date': 'Tue, 09 Jan 2018 13:25:05 GMT', 'Content-Length': '2404', 'Connection': 'keep-alive', 'Via': '1.0 csh60559 (SAS.kvfarm)', 'Access-Control-Allow-Origin': '*', 'Content-Type': 'application/json'}

# %%
r.encoding

# %%
jsonout = r.json()
jsonout
# Out:
# {'data': [{'category': 'general',
#    'data': [{'change': '+',
#      'cvalue': 1736,
#      'delta': 0,
#      'keyword': '투깝스',
#      'rank': 1,
#      'ratio': '.',
#      'score': 84,
#      'tvalue': 28.44082},
#     {'change': '+',
#      'cvalue': 422,
#      'delta': 0,
#      'keyword': '염력',
#      'rank': 2,
#      'ratio': '.',
#      'score': 138,
#      'tvalue': 27.97407},
#     {'change': '+',
#      'cvalue': 715,
#      'delta': 0,
#      'keyword': '뭉쳐야 뜬다',
#      'rank': 3,
#      'ratio': '.',
#      'score': 132,
#      'tvalue': 33.588},
#     {'change': '+',
#      'cvalue': 1021,
#      'delta': 0,
#      'keyword': '의문의 일승',
#      'rank': 4,
#      'ratio': '.',
#      'score': 99,
#      'tvalue': 21.2569},
#     {'change': '+',
#      'cvalue': 362,
#      'delta': 0,
#      'keyword': '오마이걸',
#      'rank': 5,
#      'ratio': '.',
#      'score': 120,
#      'tvalue': 19.86568},
#     {'change': '+',
#      'cvalue': 3090,
#      'delta': 0,
#      'keyword': '강식당',
#      'rank': 6,
#      'ratio': '.',
#      'score': 42,
#      'tvalue': 19.51452},
#     {'change': '+',
#      'cvalue': 2055,
#      'delta': 1,
#      'keyword': '저글러스',
#      'rank': 7,
#      'ratio': '+',
#      'score': 54,
#      'tvalue': 17.92747},
#     {'change': '+',
#      'cvalue': 78,
#      'delta': 1,
#      'keyword': '모네로',
#      'rank': 8,
#      'ratio': '-',
#      'score': 198,
#      'tvalue': 7.91751},
#     {'change': '+',
#      'cvalue': 1094,
#      'delta': 1,
#      'keyword': '막돼먹은 영애씨 시즌16',
#      'rank': 9,
#      'ratio': '+',
#      'score': 117,
#      'tvalue': 16.40265},
#     {'change': '+',
#      'cvalue': 92,
#      'delta': 1,
#      'keyword': '애간장',
#      'rank': 10,
#      'ratio': '-',
#      'score': 195,
#      'tvalue': 5.09282},
#     {'change': '+',
#      'cvalue': 90,
#      'delta': 0,
#      'keyword': '정유미',
#      'rank': 11,
#      'ratio': '.',
#      'score': 93,
#      'tvalue': 4.55405},
#     {'change': '+',
#      'cvalue': 159,
#      'delta': 0,
#      'keyword': 'kbs온에어',
#      'rank': 12,
#      'ratio': '.',
#      'score': 69,
#      'tvalue': 4.18898},
#     {'change': '+',
#      'cvalue': 61,
#      'delta': 0,
#      'keyword': '렉스턴 스포츠',
#      'rank': 13,
#      'ratio': '.',
#      'score': 66,
#      'tvalue': 4.0281},
#     {'change': '+',
#      'cvalue': 75,
#      'delta': 0,
#      'keyword': 'mbc온에어',
#      'rank': 14,
#      'ratio': '.',
#      'score': 102,
#      'tvalue': 3.39028},
#     {'change': '+',
#      'cvalue': 64,
#      'delta': 0,
#      'keyword': '인터파크티켓',
#      'rank': 15,
#      'ratio': '.',
#      'score': 51,
#      'tvalue': 2.88274},
#     {'change': '+',
#      'cvalue': 52,
#      'delta': 1,
#      'keyword': 'itq',
#      'rank': 16,
#      'ratio': '+',
#      'score': 75,
#      'tvalue': 2.80883},
#     {'change': '+',
#      'cvalue': 76,
#      'delta': 1,
#      'keyword': 'sbs 온에어',
#      'rank': 17,
#      'ratio': '-',
#      'score': 84,
#      'tvalue': 2.79476},
#     {'change': '+',
#      'cvalue': 131,
#      'delta': 0,
#      'keyword': '국세청홈택스',
#      'rank': 18,
#      'ratio': '.',
#      'score': 36,
#      'tvalue': 2.62376},
#     {'change': '+',
#      'cvalue': 52,
#      'delta': 0,
#      'keyword': '강다니엘',
#      'rank': 19,
#      'ratio': '.',
#      'score': 54,
#      'tvalue': 2.14574},
#     {'change': '+',
#      'cvalue': 59,
#      'delta': 0,
#      'keyword': 'sbs',
#      'rank': 20,
#      'ratio': 'new',
#      'score': 75,
#      'tvalue': 2.0099}]}],
#  'et': '2018-01-09T22:11:00+0900',
#  'st': '2018-01-09T22:01:00+0900',
#  'ts': '2018-01-09T22:25:00+0900'}

# %%
jsonout.keys()
# Out:
# dict_keys(['ts', 'st', 'et', 'data'])

# %%
jsonout['data']
# Out:
# [{'category': 'general',
#   'data': [{'change': '+',
#     'cvalue': 1736,
#     'delta': 0,
#     'keyword': '투깝스',
#     'rank': 1,
#     'ratio': '.',
#     'score': 84,
#     'tvalue': 28.44082},
#    {'change': '+',
#     'cvalue': 422,
#     'delta': 0,
#     'keyword': '염력',
#     'rank': 2,
#     'ratio': '.',
#     'score': 138,
#     'tvalue': 27.97407},
#    {'change': '+',
#     'cvalue': 715,
#     'delta': 0,
#     'keyword': '뭉쳐야 뜬다',
#     'rank': 3,
#     'ratio': '.',
#     'score': 132,
#     'tvalue': 33.588},
#    {'change': '+',
#     'cvalue': 1021,
#     'delta': 0,
#     'keyword': '의문의 일승',
#     'rank': 4,
#     'ratio': '.',
#     'score': 99,
#     'tvalue': 21.2569},
#    {'change': '+',
#     'cvalue': 362,
#     'delta': 0,
#     'keyword': '오마이걸',
#     'rank': 5,
#     'ratio': '.',
#     'score': 120,
#     'tvalue': 19.86568},
#    {'change': '+',
#     'cvalue': 3090,
#     'delta': 0,
#     'keyword': '강식당',
#     'rank': 6,
#     'ratio': '.',
#     'score': 42,
#     'tvalue': 19.51452},
#    {'change': '+',
#     'cvalue': 2055,
#     'delta': 1,
#     'keyword': '저글러스',
#     'rank': 7,
#     'ratio': '+',
#     'score': 54,
#     'tvalue': 17.92747},
#    {'change': '+',
#     'cvalue': 78,
#     'delta': 1,
#     'keyword': '모네로',
#     'rank': 8,
#     'ratio': '-',
#     'score': 198,
#     'tvalue': 7.91751},
#    {'change': '+',
#     'cvalue': 1094,
#     'delta': 1,
#     'keyword': '막돼먹은 영애씨 시즌16',
#     'rank': 9,
#     'ratio': '+',
#     'score': 117,
#     'tvalue': 16.40265},
#    {'change': '+',
#     'cvalue': 92,
#     'delta': 1,
#     'keyword': '애간장',
#     'rank': 10,
#     'ratio': '-',
#     'score': 195,
#     'tvalue': 5.09282},
#    {'change': '+',
#     'cvalue': 90,
#     'delta': 0,
#     'keyword': '정유미',
#     'rank': 11,
#     'ratio': '.',
#     'score': 93,
#     'tvalue': 4.55405},
#    {'change': '+',
#     'cvalue': 159,
#     'delta': 0,
#     'keyword': 'kbs온에어',
#     'rank': 12,
#     'ratio': '.',
#     'score': 69,
#     'tvalue': 4.18898},
#    {'change': '+',
#     'cvalue': 61,
#     'delta': 0,
#     'keyword': '렉스턴 스포츠',
#     'rank': 13,
#     'ratio': '.',
#     'score': 66,
#     'tvalue': 4.0281},
#    {'change': '+',
#     'cvalue': 75,
#     'delta': 0,
#     'keyword': 'mbc온에어',
#     'rank': 14,
#     'ratio': '.',
#     'score': 102,
#     'tvalue': 3.39028},
#    {'change': '+',
#     'cvalue': 64,
#     'delta': 0,
#     'keyword': '인터파크티켓',
#     'rank': 15,
#     'ratio': '.',
#     'score': 51,
#     'tvalue': 2.88274},
#    {'change': '+',
#     'cvalue': 52,
#     'delta': 1,
#     'keyword': 'itq',
#     'rank': 16,
#     'ratio': '+',
#     'score': 75,
#     'tvalue': 2.80883},
#    {'change': '+',
#     'cvalue': 76,
#     'delta': 1,
#     'keyword': 'sbs 온에어',
#     'rank': 17,
#     'ratio': '-',
#     'score': 84,
#     'tvalue': 2.79476},
#    {'change': '+',
#     'cvalue': 131,
#     'delta': 0,
#     'keyword': '국세청홈택스',
#     'rank': 18,
#     'ratio': '.',
#     'score': 36,
#     'tvalue': 2.62376},
#    {'change': '+',
#     'cvalue': 52,
#     'delta': 0,
#     'keyword': '강다니엘',
#     'rank': 19,
#     'ratio': '.',
#     'score': 54,
#     'tvalue': 2.14574},
#    {'change': '+',
#     'cvalue': 59,
#     'delta': 0,
#     'keyword': 'sbs',
#     'rank': 20,
#     'ratio': 'new',
#     'score': 75,
#     'tvalue': 2.0099}]}]

# %%
len(jsonout['data'])
# Out:
# 1

# %%
jsonout['data'][0]  # this is a dictionary
# Out:
# {'category': 'general',
#  'data': [{'change': '+',
#    'cvalue': 1736,
#    'delta': 0,
#    'keyword': '투깝스',
#    'rank': 1,
#    'ratio': '.',
#    'score': 84,
#    'tvalue': 28.44082},
#   {'change': '+',
#    'cvalue': 422,
#    'delta': 0,
#    'keyword': '염력',
#    'rank': 2,
#    'ratio': '.',
#    'score': 138,
#    'tvalue': 27.97407},
#   {'change': '+',
#    'cvalue': 715,
#    'delta': 0,
#    'keyword': '뭉쳐야 뜬다',
#    'rank': 3,
#    'ratio': '.',
#    'score': 132,
#    'tvalue': 33.588},
#   {'change': '+',
#    'cvalue': 1021,
#    'delta': 0,
#    'keyword': '의문의 일승',
#    'rank': 4,
#    'ratio': '.',
#    'score': 99,
#    'tvalue': 21.2569},
#   {'change': '+',
#    'cvalue': 362,
#    'delta': 0,
#    'keyword': '오마이걸',
#    'rank': 5,
#    'ratio': '.',
#    'score': 120,
#    'tvalue': 19.86568},
#   {'change': '+',
#    'cvalue': 3090,
#    'delta': 0,
#    'keyword': '강식당',
#    'rank': 6,
#    'ratio': '.',
#    'score': 42,
#    'tvalue': 19.51452},
#   {'change': '+',
#    'cvalue': 2055,
#    'delta': 1,
#    'keyword': '저글러스',
#    'rank': 7,
#    'ratio': '+',
#    'score': 54,
#    'tvalue': 17.92747},
#   {'change': '+',
#    'cvalue': 78,
#    'delta': 1,
#    'keyword': '모네로',
#    'rank': 8,
#    'ratio': '-',
#    'score': 198,
#    'tvalue': 7.91751},
#   {'change': '+',
#    'cvalue': 1094,
#    'delta': 1,
#    'keyword': '막돼먹은 영애씨 시즌16',
#    'rank': 9,
#    'ratio': '+',
#    'score': 117,
#    'tvalue': 16.40265},
#   {'change': '+',
#    'cvalue': 92,
#    'delta': 1,
#    'keyword': '애간장',
#    'rank': 10,
#    'ratio': '-',
#    'score': 195,
#    'tvalue': 5.09282},
#   {'change': '+',
#    'cvalue': 90,
#    'delta': 0,
#    'keyword': '정유미',
#    'rank': 11,
#    'ratio': '.',
#    'score': 93,
#    'tvalue': 4.55405},
#   {'change': '+',
#    'cvalue': 159,
#    'delta': 0,
#    'keyword': 'kbs온에어',
#    'rank': 12,
#    'ratio': '.',
#    'score': 69,
#    'tvalue': 4.18898},
#   {'change': '+',
#    'cvalue': 61,
#    'delta': 0,
#    'keyword': '렉스턴 스포츠',
#    'rank': 13,
#    'ratio': '.',
#    'score': 66,
#    'tvalue': 4.0281},
#   {'change': '+',
#    'cvalue': 75,
#    'delta': 0,
#    'keyword': 'mbc온에어',
#    'rank': 14,
#    'ratio': '.',
#    'score': 102,
#    'tvalue': 3.39028},
#   {'change': '+',
#    'cvalue': 64,
#    'delta': 0,
#    'keyword': '인터파크티켓',
#    'rank': 15,
#    'ratio': '.',
#    'score': 51,
#    'tvalue': 2.88274},
#   {'change': '+',
#    'cvalue': 52,
#    'delta': 1,
#    'keyword': 'itq',
#    'rank': 16,
#    'ratio': '+',
#    'score': 75,
#    'tvalue': 2.80883},
#   {'change': '+',
#    'cvalue': 76,
#    'delta': 1,
#    'keyword': 'sbs 온에어',
#    'rank': 17,
#    'ratio': '-',
#    'score': 84,
#    'tvalue': 2.79476},
#   {'change': '+',
#    'cvalue': 131,
#    'delta': 0,
#    'keyword': '국세청홈택스',
#    'rank': 18,
#    'ratio': '.',
#    'score': 36,
#    'tvalue': 2.62376},
#   {'change': '+',
#    'cvalue': 52,
#    'delta': 0,
#    'keyword': '강다니엘',
#    'rank': 19,
#    'ratio': '.',
#    'score': 54,
#    'tvalue': 2.14574},
#   {'change': '+',
#    'cvalue': 59,
#    'delta': 0,
#    'keyword': 'sbs',
#    'rank': 20,
#    'ratio': 'new',
#    'score': 75,
#    'tvalue': 2.0099}]}

# %%
jsonout['data'][0].keys()
# Out:
# dict_keys(['category', 'data'])

# %%
ldic = jsonout['data'][0]['data'] # this is a list of dictionaries

# %%
ldic[0]
# Out:
# {'change': '+',
#  'cvalue': 1736,
#  'delta': 0,
#  'keyword': '투깝스',
#  'rank': 1,
#  'ratio': '.',
#  'score': 84,
#  'tvalue': 28.44082}

# %%
ldic[0]['keyword']
# Out:
# '투깝스'

# %%
'투깝스' in ldic[0].values()
# Out:
# True

# %%
'keyword' in ldic[0]
# Out:
# True

# %%
import re
import requests

re.findall('<span class="ah_k">(.*?)</span>', requests.get('http://naver.com').text)[:20]
# Out:
# ['투깝스',
#  '공유',
#  '뭉쳐야 뜬다',
#  '오마이걸',
#  '저글러스',
#  '막돼먹은 영애씨 시즌16',
#  '강식당',
#  '염력',
#  '애간장',
#  '렉스턴 스포츠',
#  '정유미',
#  'tvn',
#  '티빙',
#  'LH주택공사홈페이지',
#  '브이앱',
#  'vms',
#  '국세청홈택스',
#  '윤식당',
#  '리그오브레전드',
#  '김향기']
